# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
pd.read_csv('C:\Users\akhta\Documents\GitHub\Da Project\data\Project Dataset .csv')
# Out:
#         city_name    datetime  weather_code  temperature_2m_max  \
# 0       Ahmedabad  1980-01-01           3.0                25.1
# 1       Ahmedabad  1980-01-02           0.0                24.3
# 2       Ahmedabad  1980-01-03           0.0                24.0
# 3       Ahmedabad  1980-01-04           0.0                24.2
# 4       Ahmedabad  1980-01-05           0.0                25.3
# ...           ...         ...           ...                 ...
# 814943       Āgra  2024-10-23           0.0                31.7
# 814944       Āgra  2024-10-24           0.0                31.6
# 814945       Āgra  2024-10-25           0.0                31.2
# 814946       Āgra  2024-10-26           0.0                31.3
# 814947       Āgra  2024-10-27           0.0                21.3
#
#         temperature_2m_min  temperature_2m_mean  apparent_temperature_max  \
# 0                     12.3            19.400000                      24.4
# 1                     10.9            17.500000                      23.5
# 2                     11.3            17.400000                      21.9
# 3                     12.9            17.900000                      22.0
# 4                     13.5            18.800000                      24.0
# ...                    ...                  ...                       ...
# 814943                19.5            25.700000                      33.2
# 814944                20.4            25.200000                      33.4
# 814945                19.6            24.800000                      33.1
# 814946                19.2            24.900000                      33.1
# 814947                21.3            25.089301                      24.6
#
#         apparent_temperature_min  apparent_temperature_mean  \
# 0                           10.9                  18.800000
# 1                            9.6                  16.200000
# 2                            9.3                  15.000000
# 3                            9.6                  15.100000
# 4                           10.3                  16.700000
# ...                          ...                        ...
# 814943                      21.6                  27.600000
# 814944                      21.0                  27.100000
# 814945                      20.8                  26.700000
# 814946                      20.8                  26.900000
# 814947                      24.6                  26.690527
#
#                     sunrise  ... sunshine_duration  precipitation_sum  \
# 0       1980-01-01 01:50:00  ...      34626.270000            0.00000
# 1       1980-01-02 01:50:00  ...      35318.290000            0.00000
# 2       1980-01-03 01:51:00  ...      35306.900000            0.00000
# 3       1980-01-04 01:51:00  ...      35364.770000            0.00000
# 4       1980-01-05 01:51:00  ...      35358.170000            0.00000
# ...                     ...  ...               ...                ...
# 814943  2024-10-23 00:52:00  ...      37274.930000            0.00000
# 814944  2024-10-24 00:53:00  ...      37262.630000            0.00000
# 814945  2024-10-25 00:53:00  ...      37256.010000            0.00000
# 814946  2024-10-26 00:54:00  ...      36960.290000            0.00000
# 814947  2024-10-27 00:55:00  ...      35065.687059            2.96044
#
#         rain_sum  snowfall_sum  precipitation_hours  wind_speed_10m_max  \
# 0       0.000000      0.000000                  0.0                11.8
# 1       0.000000      0.000000                  0.0                 9.3
# 2       0.000000      0.000000                  0.0                15.5
# 3       0.000000      0.000000                  0.0                19.1
# 4       0.000000      0.000000                  0.0                17.2
# ...          ...           ...                  ...                 ...
# 814943  0.000000      0.000000                  0.0                14.7
# 814944  0.000000      0.000000                  0.0                12.4
# 814945  0.000000      0.000000                  0.0                10.4
# 814946  0.000000      0.000000                  0.0                12.9
# 814947  2.946262      0.010001                  0.0                 3.7
#
#         wind_gusts_10m_max  wind_direction_10m_dominant  \
# 0                     23.4                   297.000000
# 1                     17.6                   336.000000
# 2                     32.0                    36.000000
# 3                     37.8                    39.000000
# 4                     34.9                    35.000000
# ...                    ...                          ...
# 814943                28.1                   319.000000
# 814944                25.2                   323.000000
# 814945                21.2                   303.000000
# 814946                26.3                   353.000000
# 814947                 6.1                   202.505835
#
#         shortwave_radiation_sum  et0_fao_evapotranspiration
# 0                     15.850000                    3.360000
# 1                     17.320000                    3.440000
# 2                     17.290000                    3.980000
# 3                     17.270000                    4.360000
# 4                     16.570000                    4.100000
# ...                         ...                         ...
# 814943                17.120000                    4.240000
# 814944                17.160000                    4.030000
# 814945                17.330000                    3.880000
# 814946                17.140000                    3.980000
# 814947                18.598897                    4.524246
#
# [814948 rows x 22 columns]

# %%
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 12

# %%
try:
    df = pd.read_csv('C:\Users\akhta\Documents\GitHub\Da Project\data\Project Dataset .csv')
    print("Data loaded successfully!")
except FileNotFoundError:
    print("Error: File not found. Please ensure the dataset is in the data/ folder.")
# Out:
# Data loaded successfully!

# %%
df.head()
# Out:
#    city_name    datetime  weather_code  temperature_2m_max  \
# 0  Ahmedabad  1980-01-01           3.0                25.1
# 1  Ahmedabad  1980-01-02           0.0                24.3
# 2  Ahmedabad  1980-01-03           0.0                24.0
# 3  Ahmedabad  1980-01-04           0.0                24.2
# 4  Ahmedabad  1980-01-05           0.0                25.3
#
#    temperature_2m_min  temperature_2m_mean  apparent_temperature_max  \
# 0                12.3                 19.4                      24.4
# 1                10.9                 17.5                      23.5
# 2                11.3                 17.4                      21.9
# 3                12.9                 17.9                      22.0
# 4                13.5                 18.8                      24.0
#
#    apparent_temperature_min  apparent_temperature_mean              sunrise  \
# 0                      10.9                       18.8  1980-01-01 01:50:00
# 1                       9.6                       16.2  1980-01-02 01:50:00
# 2                       9.3                       15.0  1980-01-03 01:51:00
# 3                       9.6                       15.1  1980-01-04 01:51:00
# 4                      10.3                       16.7  1980-01-05 01:51:00
#
#    ... sunshine_duration  precipitation_sum  rain_sum  snowfall_sum  \
# 0  ...          34626.27                0.0       0.0           0.0
# 1  ...          35318.29                0.0       0.0           0.0
# 2  ...          35306.90                0.0       0.0           0.0
# 3  ...          35364.77                0.0       0.0           0.0
# 4  ...          35358.17                0.0       0.0           0.0
#
#    precipitation_hours  wind_speed_10m_max  wind_gusts_10m_max  \
# 0                  0.0                11.8                23.4
# 1                  0.0                 9.3                17.6
# 2                  0.0                15.5                32.0
# 3                  0.0                19.1                37.8
# 4                  0.0                17.2                34.9
#
#    wind_direction_10m_dominant  shortwave_radiation_sum  \
# 0                        297.0                    15.85
# 1                        336.0                    17.32
# 2                         36.0                    17.29
# 3                         39.0                    17.27
# 4                         35.0                    16.57
#
#    et0_fao_evapotranspiration
# 0                        3.36
# 1                        3.44
# 2                        3.98
# 3                        4.36
# 4                        4.10
#
# [5 rows x 22 columns]

# %%
print("Dataset Info:")
df.info()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 814948 entries, 0 to 814947
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   city_name                    814948 non-null  object
#  1   datetime                     814948 non-null  object
#  2   weather_code                 814948 non-null  float64
#  3   temperature_2m_max           814948 non-null  float64
#  4   temperature_2m_min           814948 non-null  float64
#  5   temperature_2m_mean          814948 non-null  float64
#  6   apparent_temperature_max     814948 non-null  float64
#  7   apparent_temperature_min     814948 non-null  float64
#  8   apparent_temperature_mean    814948 non-null  float64
#  9   sunrise                      814948 non-null  object
#  10  sunset                       814948 non-null  object
#  11  daylight_duration            814948 non-null  float64
#  12  sunshine_duration            814948 non-null  float64
#  13  precipitation_sum            814948 non-null  float64
#  14  rain_sum                     814948 non-null  float64
#  15  snowfall_sum                 814948 non-null  float64
#  16  precipitation_hours          814948 non-null  float64
#  17  wind_speed_10m_max           814948 non-null  float64
#  18  wind_gusts_10m_max           814948 non-null  float64
#  19  wind_direction_10m_dominant  814948 non-null  float64
#  20  shortwave_radiation_sum      814948 non-null  float64
#  21  et0_fao_evapotranspiration   814948 non-null  float64
# dtypes: float64(18), object(4)
# memory usage: 136.8+ MB

# %%
missing_values = df.isnull().sum()
missing_percentage = (df.isnull().mean() * 100).round(2)

missing_data = pd.DataFrame({
    'Missing Values': missing_values,
    'Percentage (%)': missing_percentage
})

print("Missing Values Summary:")
missing_data[missing_data['Missing Values'] > 0]
# Out:
# Missing Values Summary:
# Empty DataFrame
# Columns: [Missing Values, Percentage (%)]
# Index: []

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis', yticklabels=False)
plt.title('Missing Values Heatmap', pad=20)
plt.show()

# %%
# Handle missing values
def handle_missing_values(data):
    """Handle missing values in the dataset"""
    # For temperature columns, fill with monthly mean by city
    temp_cols = ['temperature_2m_max', 'temperature_2m_min', 'temperature_2m_mean']
    for col in temp_cols:
        data[col] = data.groupby(['city_name', data['datetime'].dt.month])[col].transform(
            lambda x: x.fillna(x.mean()))
    
    # For precipitation, fill with 0 (assuming no rain)
    data['precipitation_sum'] = data['precipitation_sum'].fillna(0)
    
    # For wind speed, fill with overall mean by city
    data['wind_speed_10m_max'] = data.groupby('city_name')['wind_speed_10m_max'].transform(
        lambda x: x.fillna(x.mean()))
    
    return data

# %%
df['datetime'] = pd.to_datetime(df['datetime'])

# Apply missing value handling
df_clean = handle_missing_values(df.copy())

# Verify no missing values remain
print("Missing values after cleaning:")
print(df_clean.isnull().sum())

# %%
# Check and remove duplicates
print(f"Number of duplicates before cleaning: {df_clean.duplicated().sum()}")
df_clean = df_clean.drop_duplicates()
print(f"Number of duplicates after cleaning: {df_clean.duplicated().sum()}")

# %%
# Check data types
print("\nData types:")
print(df_clean.dtypes)

# Fix any incorrect data types (example - if city_name was numeric)
df_clean['city_name'] = df_clean['city_name'].astype('category')
# Out:
# Missing values after cleaning:
# city_name                      0
# datetime                       0
# weather_code                   0
# temperature_2m_max             0
# temperature_2m_min             0
# temperature_2m_mean            0
# apparent_temperature_max       0
# apparent_temperature_min       0
# apparent_temperature_mean      0
# sunrise                        0
# sunset                         0
# daylight_duration              0
# sunshine_duration              0
# precipitation_sum              0
# rain_sum                       0
# snowfall_sum                   0
# precipitation_hours            0
# wind_speed_10m_max             0
# wind_gusts_10m_max             0
# wind_direction_10m_dominant    0
# shortwave_radiation_sum        0
# et0_fao_evapotranspiration     0
# dtype: int64
# Number of duplicates before cleaning: 0
# Number of duplicates after cleaning: 0
#
# Data types:
# city_name                              object
# datetime                       datetime64[ns]
# weather_code                          float64
# temperature_2m_max                    float64
# temperature_2m_min                    float64
# temperature_2m_mean                   float64
# apparent_temperature_max              float64
# apparent_temperature_min              float64
# apparent_temperature_mean             float64
# sunrise                                object
# sunset                                 object
# daylight_duration                     float64
# sunshine_duration                     float64
# precipitation_sum                     float64
# rain_sum                              float64
# snowfall_sum                          float64
# precipitation_hours                   float64
# wind_speed_10m_max                    float64
# wind_gusts_10m_max                    float64
# wind_direction_10m_dominant           float64
# shortwave_radiation_sum               float64
# et0_fao_evapotranspiration            float64
# dtype: object

# %%
selected_features = [
    'city_name',
    'datetime',
    'temperature_2m_max',
    'temperature_2m_min',
    'temperature_2m_mean',
    'precipitation_sum',
    'wind_speed_10m_max'
]

df_final = df_clean[selected_features].copy()
def engineer_features(data):
    """Create new features from existing data"""
    # Extract time-based features
    data['month'] = data['datetime'].dt.month
    data['year'] = data['datetime'].dt.year
    data['day_of_year'] = data['datetime'].dt.dayofyear

# %%
def engineer_features(data):
    """Create new features from existing data"""
    # Extract time-based features
    data['month'] = data['datetime'].dt.month
    data['year'] = data['datetime'].dt.year
    data['day_of_year'] = data['datetime'].dt.dayofyear
    data['season'] = data['month'].apply(lambda x: 'Winter' if x in [12, 1, 2] else 'Spring' if x in [3, 4, 5] else 'Summer' if x in [6, 7, 8] else 'Autumn')
    data['temperature_range'] = data['temperature_2m_max'] - data['temperature_2m_min']
    data['had_precipitation'] = data['precipitation_sum'] > 0
    
    return data

df_final = engineer_features(df_final)

df_final.head()
# Out:
#    city_name   datetime  temperature_2m_max  temperature_2m_min  \
# 0  Ahmedabad 1980-01-01                25.1                12.3
# 1  Ahmedabad 1980-01-02                24.3                10.9
# 2  Ahmedabad 1980-01-03                24.0                11.3
# 3  Ahmedabad 1980-01-04                24.2                12.9
# 4  Ahmedabad 1980-01-05                25.3                13.5
#
#    temperature_2m_mean  precipitation_sum  wind_speed_10m_max  month  year  \
# 0                 19.4                0.0                11.8      1  1980
# 1                 17.5                0.0                 9.3      1  1980
# 2                 17.4                0.0                15.5      1  1980
# 3                 17.9                0.0                19.1      1  1980
# 4                 18.8                0.0                17.2      1  1980
#
#    day_of_year  season  temperature_range  had_precipitation
# 0            1  Winter               12.8              False
# 1            2  Winter               13.4              False
# 2            3  Winter               12.7              False
# 3            4  Winter               11.3              False
# 4            5  Winter               11.8              False

# %%
print(f"Number of duplicates: {df_final.duplicated().sum()}")
# Out:
# Number of duplicates: 0

# %%
numeric_cols = ['temperature_2m_max', 'temperature_2m_min', 'temperature_2m_mean', 
                'precipitation_sum', 'wind_speed_10m_max']

print("Value ranges for numeric columns:")
for col in numeric_cols:
    print(f"{col}: Min={df_final[col].min()}, Max={df_final[col].max()}")

# %%
# Check city name consistency
print("\nUnique city names:")
print(df_final['city_name'].unique())
# Out:
# Value ranges for numeric columns:
# temperature_2m_max: Min=-11.9, Max=48.1
# temperature_2m_min: Min=-17.0, Max=36.2
# temperature_2m_mean: Min=-13.8, Max=40.8
# precipitation_sum: Min=0.0, Max=494.9
# wind_speed_10m_max: Min=0.9, Max=71.7
#
# Unique city names:
# ['Ahmedabad', 'Alīgarh', 'Amritsar', 'Aurangābād', 'Bangalore', ..., 'Vasai-Virar', 'Vijayavāda', 'Vishākhapatnam', 'Vārānasi', 'Āgra']
# Length: 50
# Categories (50, object): ['Ahmedabad', 'Alīgarh', 'Amritsar', 'Aurangābād', ..., 'Vijayavāda', 'Vishākhapatnam', 'Vārānasi', 'Āgra']

# %%
# %% [markdown]
## 5. Summary Statistics and Insights (Condensed)

# %%
# Set smaller default font size
plt.rcParams.update({'font.size': 8})

# Basic statistics
print("Overall Statistics:")
display(df_final[numeric_cols].describe().round(2))

# %%
# Grouped statistics - by city (compact display)
print("\nStatistics by City:")
city_stats = df_final.groupby('city_name')[numeric_cols].agg(['mean', 'median', 'std'])
display(city_stats.style.format("{:.2f}").set_table_styles(
    [{'selector': 'th', 'props': [('font-size', '8pt')]}]
))

# %%
# Grouped statistics - by season (compact display)
print("\nStatistics by Season:")
display(df_final.groupby('season')[numeric_cols].agg(['mean', 'median', 'std']).round(2))

# %%
# Compact correlation matrix
plt.figure(figsize=(6, 5))
sns.heatmap(df_final[numeric_cols].corr(), annot=True, cmap='coolwarm', 
            center=0, annot_kws={'size': 7}, fmt='.2f')
plt.title('Variable Correlations', fontsize=9, pad=10)
plt.xticks(fontsize=7)
plt.yticks(fontsize=7)
plt.tight_layout()
plt.show()
# Out:
# Overall Statistics:
#        temperature_2m_max  temperature_2m_min  temperature_2m_mean  \
# count           814948.00           814948.00            814948.00
# mean                30.56               20.06                25.09
# std                  5.78                6.25                 5.69
# min                -11.90              -17.00               -13.80
# 25%                 27.40               15.90                22.10
# 50%                 30.60               21.70                26.00
# 75%                 33.90               25.00                28.70
# max                 48.10               36.20                40.80
#
#        precipitation_sum  wind_speed_10m_max
# count          814948.00           814948.00
# mean                2.96               14.27
# std                 8.96                5.23
# min                 0.00                0.90
# 25%                 0.00               10.20
# 50%                 0.00               13.50
# 75%                 1.60               17.40
# max               494.90               71.70
# Statistics by City:
# C:\Users\RUDRA\AppData\Local\Temp\ipykernel_16656\3811043748.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   city_stats = df_final.groupby('city_name')[numeric_cols].agg(['mean', 'median', 'std'])
# <style type="text/css">
# #T_84d1f th {
#   font-size: 8pt;
# }
# </style>
# <table id="T_84d1f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84d1f_level0_col0" class="col_heading level0 col0" colspan="3">temperature_2m_max</th>
#       <th id="T_84d1f_level0_col3" class="col_heading level0 col3" colspan="3">temperature_2m_min</th>
#       <th id="T_84d1f_level0_col6" class="col_heading level0 col6" colspan="3">temperature_2m_mean</th>
#       <th id="T_84d1f_level0_col9" class="col_heading level0 col9" colspan="3">precipitation_sum</th>
#       <th id="T_84d1f_level0_col12" class="col_heading level0 col12" colspan="3">wind_speed_10m_max</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_84d1f_level1_col0" class="col_heading level1 col0" >mean</th>
#       <th id="T_84d1f_level1_col1" class="col_heading level1 col1" >median</th>
#       <th id="T_84d1f_level1_col2" class="col_heading level1 col2" >std</th>
#       <th id="T_84d1f_level1_col3" class="col_heading level1 col3" >mean</th>
#       <th id="T_84d1f_level1_col4" class="col_heading level1 col4" >median</th>
#       <th id="T_84d1f_level1_col5" class="col_heading level1 col5" >std</th>
#       <th id="T_84d1f_level1_col6" class="col_heading level1 col6" >mean</th>
#       <th id="T_84d1f_level1_col7" class="col_heading level1 col7" >median</th>
#       <th id="T_84d1f_level1_col8" class="col_heading level1 col8" >std</th>
#       <th id="T_84d1f_level1_col9" class="col_heading level1 col9" >mean</th>
#       <th id="T_84d1f_level1_col10" class="col_heading level1 col10" >median</th>
#       <th id="T_84d1f_level1_col11" class="col_heading level1 col11" >std</th>
#       <th id="T_84d1f_level1_col12" class="col_heading level1 col12" >mean</th>
#       <th id="T_84d1f_level1_col13" class="col_heading level1 col13" >median</th>
#       <th id="T_84d1f_level1_col14" class="col_heading level1 col14" >std</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >city_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84d1f_level0_row0" class="row_heading level0 row0" >Ahmedabad</th>
#       <td id="T_84d1f_row0_col0" class="data row0 col0" >33.14</td>
#       <td id="T_84d1f_row0_col1" class="data row0 col1" >32.40</td>
#       <td id="T_84d1f_row0_col2" class="data row0 col2" >4.54</td>
#       <td id="T_84d1f_row0_col3" class="data row0 col3" >21.47</td>
#       <td id="T_84d1f_row0_col4" class="data row0 col4" >22.95</td>
#       <td id="T_84d1f_row0_col5" class="data row0 col5" >5.01</td>
#       <td id="T_84d1f_row0_col6" class="data row0 col6" >27.04</td>
#       <td id="T_84d1f_row0_col7" class="data row0 col7" >27.40</td>
#       <td id="T_84d1f_row0_col8" class="data row0 col8" >4.38</td>
#       <td id="T_84d1f_row0_col9" class="data row0 col9" >2.02</td>
#       <td id="T_84d1f_row0_col10" class="data row0 col10" >0.00</td>
#       <td id="T_84d1f_row0_col11" class="data row0 col11" >9.89</td>
#       <td id="T_84d1f_row0_col12" class="data row0 col12" >14.15</td>
#       <td id="T_84d1f_row0_col13" class="data row0 col13" >13.60</td>
#       <td id="T_84d1f_row0_col14" class="data row0 col14" >4.22</td>
#     </tr>
#     <tr>
#       <th id="T_84d1f_level0_row1" class="row_heading level0 row1" >Alīgarh</th>
#       <td id="T_84d1f_row1_col0" class="data row1 col0" >30.62</td>
#       <td id="T_84d1f_row1_col1" class="data row1 col1" >31.30</td>
#       <td id="T_84d1f_row1_col2" class="data row1 col2" >6.59</td>
#       <td id="T_84d1f_row1_col3" class="data row1 col3" >18.93</td>
#       <td id="T_84d1f_row1_col4" class="data row1 col4" >20.20</td>
#       <td id="T_84d1f_row1_col5" class="data row1 col5" >7.31</td>
#       <td id="T_84d1f_row1_col6" class="data row1 col6" >24.67</td>
#       <td id="T_84d1f_row1_col7" class="data row1 col7" >26.40</td>
#       <td id="T_84d1f_row1_col8" class="data row1 col8" >6.84</td>
#       <td id="T_84d1f_row1_col9" class="data row1 col9" >2.14</td>
#       <td id="T_84d1f_row1_col10" class="data row1 col10" >0.00</td>
#       <td id="T_84d1f_row1_col11" class="data row1 col11" >7.46</td>
#       <td id="T_84d1f_row1_col12" class="data row1 col12" >14.19</td>
#       <td id="T_84d1f_row1_col13" class="data row1 col13" >13.50</td>
#       <td id="T_84d1f_row1_col14" class="data row1 col14" >4.79</td>
#     </tr>
#     <tr>
#       <th id="T_84d1f_level0_row2" class="row_heading level0 row2" >Amritsar</th>
#       <td id="T_84d1f_row2_col0" class="data row2 col0" >29.20</td>
#       <td id="T_84d1f_row2_col1" class="data row2 col1" >30.70</td>
#       <td id="T_84d1f_row2_col2" class="data row2 col2" >7.46</td>
#       <td id="T_84d1f_row2_col3" class="data row2 col3" >17.15</td>
#       <td id="T_84d1f_row2_col4" class="data row2 col4" >17.80</td>
#       <td id="T_84d1f_row2_col5" class="data row2 col5" >7.74</td>
#       <td id="T_84d1f_row2_col6" class="data row2 col6" >23.02</td>
#       <td id="T_84d1f_row2_col7" class="data row2 col7" >24.60</td>
#       <td id="T_84d1f_row2_col8" class="data row2 col8" >7.56</td>
#       <td id="T_84d1f_row2_col9" class="data row2 col9" >2.16</td>
#       <td id="T_84d1f_row2_col10" class="data row2 col10" >0.00</td>
#       <td id="T_84d1f_row2_col11" class="data row2 col11" >6.39</td>
#       <td id="T_84d1f_row2_col12" class="data row2 col12" >11.69</td>
#       <td id="T_84d1f_row2_col13" class="data row2 col13" >10.70</td>
#       <td id="T_84d1f_row2_col14" class="data row2 col14" >3.92</td>
#     </tr>
#     <tr>
#       <th id="T_84d1f_level0_row3" class="row_heading level0 row3" >Aurangābād</th>
#       <td id="T_84d1f_row3_col0" class="data row3 col0" >31.34</td>
#       <td id="T_84d1f_row3_col1" class="data row3 col1" >30.00</td>
#       <td id="T_84d1f_row3_col2" class="data row3 col2" >4.39</td>
#       <td id="T_84d1f_row3_col3" class="data row3 col3" >20.29</td>
#       <td id="T_84d1f_row3_col4" class="data row3 col4" >21.30</td>
#       <td id="T_84d1f_row3_col5" class="data row3 col5" >3.71</td>
#       <td id="T_84d1f_row3_col6" class="data row3 col6" >25.64</td>
#       <td id="T_84d1f_row3_col7" class="data row3 col7" >24.90</td>
#       <td id="T_84d1f_row3_col8" class="data row3 col8" >3.69</td>
#       <td id="T_84d1f_row3_col9" class="data row3 col9" >2.36</td>
#       <td id="T_84d1f_row3_col10" class="data row3 col10" >0.00</td>
#       <td id="T_84d1f_row3_col11" class="data row3 col11" >7.96</td>
#       <td id="T_84d1f_row3_col12" class="data row3 col12" >14.34</td>
#       <td id="T_84d1f_row3_col13" class="data row3 col13" >13.40</td>
#       <td id="T_84d1f_row3_col14" class="data row3 col14" >4.82</td>
#     </tr>
#     <tr>
#       <th id="T_84d1f_level0_row4" class="row_heading level0 row4" >Bangalore</th>
#       <td id="T_84d1f_row4_col0" class="data row4 col0" >28.19</td>
#       <td id="T_84d1f_row4_col1" class="data row4 col1" >27.40</td>
#       <td id="T_84d1f_row4_col2" class="data row4 col2" >3.04</td>
#       <td id="T_84d1f_row4_col3" class="data row4 col3" >18.26</td>
#       <td id="T_84d1f_row4_col4" class="data row4 col4" >19.00</td>
#       <td id="T_84d1f_row4_col5" class="data row4 col5" >2.50</td>
#       <td id="T_84d1f_row4_col6" class="data row4 col6" >22.84</td>
#       <td id="T_84d1f_row4_col7" class="data row4 col7" >22.50</td>
#       <td id="T_84d1f_row4_col8" class="data row4 col8" >2.34</td>
#       <td id="T_84d1f_row4_col9" class="data row4 col9" >2.48</td>
#       <td id="T_84d1f_row4_col10" class="data row4 col10" >0.10</td>
#       <td id
# Statistics by Season:
#        temperature_2m_max              temperature_2m_min               \
#                      mean median   std               mean median   std
# season
# Autumn              29.77   30.0  3.29              20.13   21.0  4.50
# Spring              35.04   35.6  5.20              21.80   22.5  4.89
# Summer              31.94   31.5  4.33              25.20   25.4  2.53
# Winter              25.33   25.8  5.19              12.90   13.0  5.06
#
#        temperature_2m_mean              precipitation_sum                \
#                       mean median   std              mean median    std
# season
# Autumn               24.71   25.4  3.52              2.70    0.0   8.29
# Spring               28.35   29.0  4.79              0.84    0.0   3.93
# Summer               28.24   28.0  3.31              7.67    3.0  13.84
# Winter               18.89   19.3  4.96              0.56    0.0   3.30
#
#        wind_speed_10m_max
#                      mean median   std
# season
# Autumn              11.97   11.1  4.29
# Spring              16.08   15.8  4.80
# Summer              16.70   16.3  5.90
# Winter              12.26   11.5  3.79

# %%
## 6. Patterns & Trends (Compact with Better Legend)

# %%
# Temperature trends with better legend placement
plt.figure(figsize=(9, 4))
for city in df_final['city_name'].unique():
    city_data = df_final[df_final['city_name'] == city]
    plt.plot(city_data['datetime'], city_data['temperature_2m_mean'], 
             linewidth=1, label=city)

plt.title('Temperature Trends by City', fontsize=9, pad=10)
plt.xlabel('Date', fontsize=7)
plt.ylabel('Temp (°C)', fontsize=7)
plt.legend(prop={'size': 6}, framealpha=0.5, 
           bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\RUDRA\AppData\Local\Temp\ipykernel_16656\966596728.py:17: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
# Monthly Temperature Plot (compact with better legend)
plt.figure(figsize=(10, 5))
ax = sns.lineplot(data=df_final, x='month', y='temperature_2m_mean', hue='city_name',
                 ci=None, estimator='mean', marker='o', markersize=5, linewidth=1)
plt.title('Average Monthly Temperature by City', fontsize=10, pad=10)
plt.xlabel('Month', fontsize=8)
plt.ylabel('Mean Temperature (°C)', fontsize=8)
plt.xticks(range(1, 13), ['J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D'],
          fontsize=7)
plt.yticks(fontsize=7)
plt.grid(True, alpha=0.3)

# Move legend outside and make it compact
plt.legend(title='City', bbox_to_anchor=(1.05, 1), loc='upper left', 
          fontsize=7, title_fontsize=8, framealpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\RUDRA\AppData\Local\Temp\ipykernel_16656\38798069.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.lineplot(data=df_final, x='month', y='temperature_2m_mean', hue='city_name',

# %%
plt.figure(figsize=(12, 5))  # Wider figure for better visibility

# Create the bar plot with consistent spacing
ax = sns.barplot(data=df_final, x='city_name', y='precipitation_sum',
                estimator=np.sum, ci=None, 
                palette="Blues_d",  # Darker palette for better visibility
                saturation=0.8,    # More vibrant colors
                width=0.7)         # Optimal bar width

# Improve visibility of all elements
plt.title('Total Precipitation by City', fontsize=12, pad=15, weight='bold')
plt.xlabel('City', fontsize=10, labelpad=10)
plt.ylabel('Total Precipitation (mm)', fontsize=10, labelpad=10)

# Format ticks and labels
plt.xticks(fontsize=9, rotation=45, ha='right')  # Better angled labels
plt.yticks(fontsize=9)
plt.grid(True, axis='y', alpha=0.2, linestyle='--')

# Ensure equal spacing between all bars
positions = range(len(df_final['city_name'].unique()))
ax.set_xticks([p for p in positions])
ax.set_xticklabels(df_final['city_name'].unique())

# Add value labels on top of each bar
for p in ax.patches:
    ax.annotate(f"{p.get_height():.1f}", 
               (p.get_x() + p.get_width() / 2., p.get_height()),
               ha='center', va='center', 
               xytext=(0, 5), textcoords='offset points',
               fontsize=8)

# Adjust layout
ax.margins(x=0.03)  # Tight but consistent margins
plt.tight_layout()
plt.show()
# Out:
# C:\Users\RUDRA\AppData\Local\Temp\ipykernel_16656\2895824.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(data=df_final, x='city_name', y='precipitation_sum',
# C:\Users\RUDRA\AppData\Local\Temp\ipykernel_16656\2895824.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=df_final, x='city_name', y='precipitation_sum',

# %%
# Anomaly Detection (compact output)
print("\nTemperature Anomalies (3σ from mean):")
for city in df_final['city_name'].unique():
    city_data = df_final[df_final['city_name'] == city]
    mean_temp = city_data['temperature_2m_mean'].mean()
    std_temp = city_data['temperature_2m_mean'].std()
    
    anomalies = city_data[
        (city_data['temperature_2m_mean'] > mean_temp + 3*std_temp) | 
        (city_data['temperature_2m_mean'] < mean_temp - 3*std_temp)
    ]
    
    if not anomalies.empty:
        print(f"\n{city}:")
        display(anomalies[['datetime', 'temperature_2m_mean']].style.format({
            'temperature_2m_mean': '{:.1f}°C',
            'datetime': lambda x: x.strftime('%Y-%m-%d') if pd.notnull(x) else ''
        }).set_table_styles([{
            'selector': 'th',
            'props': [('font-size', '8pt')]
        }]))
# Out:
# Temperature Anomalies (3σ from mean):
#
# Ahmedabad:
# <style type="text/css">
# #T_78de7 th {
#   font-size: 8pt;
# }
# </style>
# <table id="T_78de7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78de7_level0_col0" class="col_heading level0 col0" >datetime</th>
#       <th id="T_78de7_level0_col1" class="col_heading level0 col1" >temperature_2m_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78de7_level0_row0" class="row_heading level0 row0" >183014</th>
#       <td id="T_78de7_row0_col0" class="data row0 col0" >1990-12-31</td>
#       <td id="T_78de7_row0_col1" class="data row0 col1" >13.8°C</td>
#     </tr>
#     <tr>
#       <th id="T_78de7_level0_row1" class="row_heading level0 row1" >183015</th>
#       <td id="T_78de7_row1_col0" class="data row1 col0" >1991-01-01</td>
#       <td id="T_78de7_row1_col1" class="data row1 col1" >13.8°C</td>
#     </tr>
#     <tr>
#       <th id="T_78de7_level0_row2" class="row_heading level0 row2" >364557</th>
#       <td id="T_78de7_row2_col0" class="data row2 col0" >2008-02-07</td>
#       <td id="T_78de7_row2_col1" class="data row2 col1" >13.5°C</td>
#     </tr>
#   </tbody>
# </table>
# Bangalore:
# <style type="text/css">
# #T_c5c99 th {
#   font-size: 8pt;
# }
# </style>
# <table id="T_c5c99">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5c99_level0_col0" class="col_heading level0 col0" >datetime</th>
#       <th id="T_c5c99_level0_col1" class="col_heading level0 col1" >temperature_2m_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5c99_level0_row0" class="row_heading level0 row0" >15321</th>
#       <td id="T_c5c99_row0_col0" class="data row0 col0" >1981-12-10</td>
#       <td id="T_c5c99_row0_col1" class="data row0 col1" >15.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_c5c99_level0_row1" class="row_heading level0 row1" >198476</th>
#       <td id="T_c5c99_row1_col0" class="data row1 col0" >1993-05-03</td>
#       <td id="T_c5c99_row1_col1" class="data row1 col1" >29.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_c5c99_level0_row2" class="row_heading level0 row2" >200287</th>
#       <td id="T_c5c99_row2_col0" class="data row2 col0" >1998-04-18</td>
#       <td id="T_c5c99_row2_col1" class="data row2 col1" >30.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_c5c99_level0_row3" class="row_heading level0 row3" >558956</th>
#       <td id="T_c5c99_row3_col0" class="data row3 col0" >2010-04-11</td>
#       <td id="T_c5c99_row3_col1" class="data row3 col1" >30.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_c5c99_level0_row4" class="row_heading level0 row4" >561160</th>
#       <td id="T_c5c99_row4_col0" class="data row4 col0" >2016-04-23</td>
#       <td id="T_c5c99_row4_col1" class="data row4 col1" >29.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_c5c99_level0_row5" class="row_heading level0 row5" >561161</th>
#       <td id="T_c5c99_row5_col0" class="data row5 col0" >2016-04-24</td>
#       <td id="T_c5c99_row5_col1" class="data row5 col1" >30.4°C</td>
#     </tr>
#     <tr>
#       <th id="T_c5c99_level0_row6" class="row_heading level0 row6" >735453</th>
#       <td id="T_c5c99_row6_col0" class="data row6 col0" >2024-04-06</td>
#       <td id="T_c5c99_row6_col1" class="data row6 col1" >29.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_c5c99_level0_row7" class="row_heading level0 row7" >735465</th>
#       <td id="T_c5c99_row7_col0" class="data row7 col0" >2024-04-18</td>
#       <td id="T_c5c99_row7_col1" class="data row7 col1" >30.6°C</td>
#     </tr>
#     <tr>
#       <th id="T_c5c99_level0_row8" class="row_heading level0 row8" >735466</th>
#       <td id="T_c5c99_row8_col0" class="data row8 col0" >2024-04-19</td>
#       <td id="T_c5c99_row8_col1" class="data row8 col1" >30.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_c5c99_level0_row9" class="row_heading level0 row9" >735467</th>
#       <td id="T_c5c99_row9_col0" class="data row9 col0" >2024-04-20</td>
#       <td id="T_c5c99_row9_col1" class="data row9 col1" >29.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_c5c99_level0_row10" class="row_heading level0 row10" >735468</th>
#       <td id="T_c5c99_row10_col0" class="data row10 col0" >2024-04-21</td>
#       <td id="T_c5c99_row10_col1" class="data row10 col1" >30.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_c5c99_level0_row11" class="row_heading level0 row11" >735469</th>
#       <td id="T_c5c99_row11_col0" class="data row11 col0" >2024-04-22</td>
#       <td id="T_c5c99_row11_col1" class="data row11 col1" >29.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_c5c99_level0_row12" class="row_heading level0 row12" >735471</th>
#       <td id="T_c5c99_row12_col0" class="data row12 col0" >2024-04-24</td>
#       <td id="T_c5c99_row12_col1" class="data row12 col1" >29.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_c5c99_level0_row13" class="row_heading level0 row13" >735472</th>
#       <td id="T_c5c99_row13_col0" class="data row13 col0" >2024-04-25</td>
#       <td id="T_c5c99_row13_col1" class="data row13 col1" >30.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_c5c99_level0_row14" class="row_heading level0 row14" >735473</th>
#       <td id="T_c5c99_row14_col0" class="data row14 col0" >2024-04-26</td>
#       <td id="T_c5c99_row14_col1" class="data row14 col1" >30.1°C</td>
#     </tr>
#     <tr>
#       <th id="T_c5c99_level0_row15" class="row_heading level0 row15" >735475</th>
#       <td id="T_c5c99_row15_col0" class="data row15 col0" >2024-04-28</td>
#       <td id="T_c5c99_row15_col1" class="data row15 col1" >30.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_c5c99_level0_row16" class="row_heading level0 row16" >735476</th>
#       <td id="T_c5c99_row16_col0" class="data row16 col0" >2024-04-29</td>
#       <td id="T_c5c99_row16_col1" class="data row16 col1" >30.3°C</td>
#     </tr>
#     <tr>
#       <th id="T_c5c99_level0_row17" class="row_heading level0 row17" >735477</th>
#       <td id="T_c5c99_row17_col0" class="data row17 col0" >2024-04-30</td>
#       <td id="T_c5c99_row17_col1" class="data row17 col1" >30.7°C</td>
#     </tr>
#     <tr>
#       <th id="T_c5c99_level0_row18" class="row_heading level0 row18" >735478</th>
#       <td id="T_c5c99_row18_col0" class="data row18 col0" >2024-05-01</td>
#       <td id="T_c5c99_row18_col1" class="data row18 col1" >31.7°C</td>
#     </tr>
#     <tr>
#       <th id="T_c5c99_level0_row19" class="row_heading level0 row19" >735479</th>
#       <td id="T_c5c99_row19_col0" class="data row19 col0" >2024-05-02</td>
#       <td id="T_c5c99_row19_col1" class="data row19 col1" >31.1°C</td>
#     </tr>
#     <tr>
#       <th id="T_c5c99_level0_row20" class="row_heading level0 row20" >735482</th>
#       <td id="T_c5c99_row20_col0" class="data row20 col0" >2024-05-05</td>
#       <td id="T_c5c99_row20_col1" class="data row20 col1" >30.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_c5c99_level0_row21" class="row_heading level0 row21" >735483</th>
#       <td id="T_c5c99_row21_col0" class="data row21 col0" >2024-05-06</td>
#       <td id="T_c5c99_row21_col1" class="data row21 col1" >30.4°C</td>
#     </tr>
#   </tbody>
# </table>
# Kalyān:
# <style type="text/css">
# #T_49ebf th {
#   font-size: 8pt;
# }
# </style>
# <table id="T_49ebf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49ebf_level0_col0" class="col_heading level0 col0" >datetime</th>
#       <th id="T_49ebf_level0_col1" class="col_heading level0 col1" >temperature_2m_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49ebf_level0_row0" class="row_heading level0 row0" >80724</th>
#       <td id="T_49ebf_row0_col0" class="data row0 col0" >1980-12-24</td>
#       <td id="T_49ebf_row0_col1" class="data row0 col1" >19.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row1" class="row_heading level0 row1" >80725</th>
#       <td id="T_49ebf_row1_col0" class="data row1 col0" >1980-12-25</td>
#       <td id="T_49ebf_row1_col1" class="data row1 col1" >18.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row2" class="row_heading level0 row2" >82303</th>
#       <td id="T_49ebf_row2_col0" class="data row2 col0" >1985-04-21</td>
#       <td id="T_49ebf_row2_col1" class="data row2 col1" >34.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row3" class="row_heading level0 row3" >263359</th>
#       <td id="T_49ebf_row3_col0" class="data row3 col0" >1991-01-01</td>
#       <td id="T_49ebf_row3_col1" class="data row3 col1" >18.6°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row4" class="row_heading level0 row4" >263360</th>
#       <td id="T_49ebf_row4_col0" class="data row4 col0" >1991-01-02</td>
#       <td id="T_49ebf_row4_col1" class="data row4 col1" >17.8°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row5" class="row_heading level0 row5" >263361</th>
#       <td id="T_49ebf_row5_col0" class="data row5 col0" >1991-01-03</td>
#       <td id="T_49ebf_row5_col1" class="data row5 col1" >18.8°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row6" class="row_heading level0 row6" >264469</th>
#       <td id="T_49ebf_row6_col0" class="data row6 col0" >1994-01-15</td>
#       <td id="T_49ebf_row6_col1" class="data row6 col1" >19.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row7" class="row_heading level0 row7" >264828</th>
#       <td id="T_49ebf_row7_col0" class="data row7 col0" >1995-01-09</td>
#       <td id="T_49ebf_row7_col1" class="data row7 col1" >18.8°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row8" class="row_heading level0 row8" >442329</th>
#       <td id="T_49ebf_row8_col0" class="data row8 col0" >2000-12-31</td>
#       <td id="T_49ebf_row8_col1" class="data row8 col1" >19.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row9" class="row_heading level0 row9" >442330</th>
#       <td id="T_49ebf_row9_col0" class="data row9 col0" >2001-01-01</td>
#       <td id="T_49ebf_row9_col1" class="data row9 col1" >19.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row10" class="row_heading level0 row10" >443551</th>
#       <td id="T_49ebf_row10_col0" class="data row10 col0" >2004-05-06</td>
#       <td id="T_49ebf_row10_col1" class="data row10 col1" >34.6°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row11" class="row_heading level0 row11" >444920</th>
#       <td id="T_49ebf_row11_col0" class="data row11 col0" >2008-02-04</td>
#       <td id="T_49ebf_row11_col1" class="data row11 col1" >19.1°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row12" class="row_heading level0 row12" >444921</th>
#       <td id="T_49ebf_row12_col0" class="data row12 col0" >2008-02-05</td>
#       <td id="T_49ebf_row12_col1" class="data row12 col1" >18.4°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row13" class="row_heading level0 row13" >444923</th>
#       <td id="T_49ebf_row13_col0" class="data row13 col0" >2008-02-07</td>
#       <td id="T_49ebf_row13_col1" class="data row13 col1" >17.4°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row14" class="row_heading level0 row14" >444924</th>
#       <td id="T_49ebf_row14_col0" class="data row14 col0" >2008-02-08</td>
#       <td id="T_49ebf_row14_col1" class="data row14 col1" >17.3°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row15" class="row_heading level0 row15" >627917</th>
#       <td id="T_49ebf_row15_col0" class="data row15 col0" >2019-02-08</td>
#       <td id="T_49ebf_row15_col1" class="data row15 col1" >19.1°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row16" class="row_heading level0 row16" >627995</th>
#       <td id="T_49ebf_row16_col0" class="data row16 col0" >2019-04-27</td>
#       <td id="T_49ebf_row16_col1" class="data row16 col1" >34.4°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row17" class="row_heading level0 row17" >765628</th>
#       <td id="T_49ebf_row17_col0" class="data row17 col0" >2020-01-17</td>
#       <td id="T_49ebf_row17_col1" class="data row17 col1" >18.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row18" class="row_heading level0 row18" >766112</th>
#       <td id="T_49ebf_row18_col0" class="data row18 col0" >2021-05-15</td>
#       <td id="T_49ebf_row18_col1" class="data row18 col1" >34.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row19" class="row_heading level0 row19" >766352</th>
#       <td id="T_49ebf_row19_col0" class="data row19 col0" >2022-01-10</td>
#       <td id="T_49ebf_row19_col1" class="data row19 col1" >19.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row20" class="row_heading level0 row20" >766366</th>
#       <td id="T_49ebf_row20_col0" class="data row20 col0" >2022-01-24</td>
#       <td id="T_49ebf_row20_col1" class="data row20 col1" >17.8°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row21" class="row_heading level0 row21" >766453</th>
#       <td id="T_49ebf_row21_col0" class="data row21 col0" >2022-04-21</td>
#       <td id="T_49ebf_row21_col1" class="data row21 col1" >34.4°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row22" class="row_heading level0 row22" >766454</th>
#       <td id="T_49ebf_row22_col0" class="data row22 col0" >2022-04-22</td>
#       <td id="T_49ebf_row22_col1" class="data row22 col1" >34.1°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row23" class="row_heading level0 row23" >766459</th>
#       <td id="T_49ebf_row23_col0" class="data row23 col0" >2022-04-27</td>
#       <td id="T_49ebf_row23_col1" class="data row23 col1" >34.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row24" class="row_heading level0 row24" >766810</th>
#       <td id="T_49ebf_row24_col0" class="data row24 col0" >2023-04-13</td>
#       <td id="T_49ebf_row24_col1" class="data row24 col1" >33.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row25" class="row_heading level0 row25" >766815</th>
#       <td id="T_49ebf_row25_col0" class="data row25 col0" >2023-04-18</td>
#       <td id="T_49ebf_row25_col1" class="data row25 col1" >34.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row26" class="row_heading level0 row26" >766816</th>
#       <td id="T_49ebf_row26_col0" class="data row26 col0" >2023-04-19</td>
#       <td id="T_49ebf_row26_col1" class="data row26 col1" >34.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row27" class="row_heading level0 row27" >767178</th>
#       <td id="T_49ebf_row27_col0" class="data row27 col0" >2024-04-15</td>
#       <td id="T_49ebf_row27_col1" class="data row27 col1" >34.7°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row28" class="row_heading level0 row28" >767179</th>
#       <td id="T_49ebf_row28_col0" class="data row28 col0" >2024-04-16</td>
#       <td id="T_49ebf_row28_col1" class="data row28 col1" >36.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row29" class="row_heading level0 row29" >767190</th>
#       <td id="T_49ebf_row29_col0" class="data row29 col0" >2024-04-27</td>
#       <td id="T_49ebf_row29_col1" class="data row29 col1" >34.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row30" class="row_heading level0 row30" >767191</th>
#       <td id="T_49ebf_row30_col0" class="data row30 col0" >2024-04-28</td>
#       <td id="T_49ebf_row30_col1" class="data row30 col1" >35.7°C</td>
#     </tr>
#     <tr>
#       <th id="T_49ebf_level0_row31" clas
# Mumbai:
# <style type="text/css">
# #T_df85a th {
#   font-size: 8pt;
# }
# </style>
# <table id="T_df85a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df85a_level0_col0" class="col_heading level0 col0" >datetime</th>
#       <th id="T_df85a_level0_col1" class="col_heading level0 col1" >temperature_2m_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df85a_level0_row0" class="row_heading level0 row0" >109948</th>
#       <td id="T_df85a_row0_col0" class="data row0 col0" >1980-12-24</td>
#       <td id="T_df85a_row0_col1" class="data row0 col1" >20.7°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row1" class="row_heading level0 row1" >109949</th>
#       <td id="T_df85a_row1_col0" class="data row1 col0" >1980-12-25</td>
#       <td id="T_df85a_row1_col1" class="data row1 col1" >20.1°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row2" class="row_heading level0 row2" >109963</th>
#       <td id="T_df85a_row2_col0" class="data row2 col0" >1981-01-08</td>
#       <td id="T_df85a_row2_col1" class="data row2 col1" >20.7°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row3" class="row_heading level0 row3" >111071</th>
#       <td id="T_df85a_row3_col0" class="data row3 col0" >1984-01-21</td>
#       <td id="T_df85a_row3_col1" class="data row3 col1" >20.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row4" class="row_heading level0 row4" >111072</th>
#       <td id="T_df85a_row4_col0" class="data row4 col0" >1984-01-22</td>
#       <td id="T_df85a_row4_col1" class="data row4 col1" >20.1°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row5" class="row_heading level0 row5" >111527</th>
#       <td id="T_df85a_row5_col0" class="data row5 col0" >1985-04-21</td>
#       <td id="T_df85a_row5_col1" class="data row5 col1" >33.3°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row6" class="row_heading level0 row6" >112131</th>
#       <td id="T_df85a_row6_col0" class="data row6 col0" >1986-12-16</td>
#       <td id="T_df85a_row6_col1" class="data row6 col1" >20.7°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row7" class="row_heading level0 row7" >112132</th>
#       <td id="T_df85a_row7_col0" class="data row7 col0" >1986-12-17</td>
#       <td id="T_df85a_row7_col1" class="data row7 col1" >20.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row8" class="row_heading level0 row8" >292574</th>
#       <td id="T_df85a_row8_col0" class="data row8 col0" >1990-12-31</td>
#       <td id="T_df85a_row8_col1" class="data row8 col1" >20.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row9" class="row_heading level0 row9" >292575</th>
#       <td id="T_df85a_row9_col0" class="data row9 col0" >1991-01-01</td>
#       <td id="T_df85a_row9_col1" class="data row9 col1" >19.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row10" class="row_heading level0 row10" >292576</th>
#       <td id="T_df85a_row10_col0" class="data row10 col0" >1991-01-02</td>
#       <td id="T_df85a_row10_col1" class="data row10 col1" >19.6°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row11" class="row_heading level0 row11" >292577</th>
#       <td id="T_df85a_row11_col0" class="data row11 col0" >1991-01-03</td>
#       <td id="T_df85a_row11_col1" class="data row11 col1" >20.7°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row12" class="row_heading level0 row12" >294044</th>
#       <td id="T_df85a_row12_col0" class="data row12 col0" >1995-01-09</td>
#       <td id="T_df85a_row12_col1" class="data row12 col1" >20.4°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row13" class="row_heading level0 row13" >294787</th>
#       <td id="T_df85a_row13_col0" class="data row13 col0" >1997-01-21</td>
#       <td id="T_df85a_row13_col1" class="data row13 col1" >20.4°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row14" class="row_heading level0 row14" >471553</th>
#       <td id="T_df85a_row14_col0" class="data row14 col0" >2000-12-31</td>
#       <td id="T_df85a_row14_col1" class="data row14 col1" >20.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row15" class="row_heading level0 row15" >473064</th>
#       <td id="T_df85a_row15_col0" class="data row15 col0" >2005-02-19</td>
#       <td id="T_df85a_row15_col1" class="data row15 col1" >20.7°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row16" class="row_heading level0 row16" >474144</th>
#       <td id="T_df85a_row16_col0" class="data row16 col0" >2008-02-04</td>
#       <td id="T_df85a_row16_col1" class="data row16 col1" >20.1°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row17" class="row_heading level0 row17" >474145</th>
#       <td id="T_df85a_row17_col0" class="data row17 col0" >2008-02-05</td>
#       <td id="T_df85a_row17_col1" class="data row17 col1" >19.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row18" class="row_heading level0 row18" >474147</th>
#       <td id="T_df85a_row18_col0" class="data row18 col0" >2008-02-07</td>
#       <td id="T_df85a_row18_col1" class="data row18 col1" >18.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row19" class="row_heading level0 row19" >474148</th>
#       <td id="T_df85a_row19_col0" class="data row19 col0" >2008-02-08</td>
#       <td id="T_df85a_row19_col1" class="data row19 col1" >18.6°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row20" class="row_heading level0 row20" >657133</th>
#       <td id="T_df85a_row20_col0" class="data row20 col0" >2019-02-08</td>
#       <td id="T_df85a_row20_col1" class="data row20 col1" >19.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row21" class="row_heading level0 row21" >657134</th>
#       <td id="T_df85a_row21_col0" class="data row21 col0" >2019-02-09</td>
#       <td id="T_df85a_row21_col1" class="data row21 col1" >20.3°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row22" class="row_heading level0 row22" >779723</th>
#       <td id="T_df85a_row22_col0" class="data row22 col0" >2020-01-16</td>
#       <td id="T_df85a_row22_col1" class="data row22 col1" >20.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row23" class="row_heading level0 row23" >779724</th>
#       <td id="T_df85a_row23_col0" class="data row23 col0" >2020-01-17</td>
#       <td id="T_df85a_row23_col1" class="data row23 col1" >19.7°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row24" class="row_heading level0 row24" >780448</th>
#       <td id="T_df85a_row24_col0" class="data row24 col0" >2022-01-10</td>
#       <td id="T_df85a_row24_col1" class="data row24 col1" >19.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row25" class="row_heading level0 row25" >780449</th>
#       <td id="T_df85a_row25_col0" class="data row25 col0" >2022-01-11</td>
#       <td id="T_df85a_row25_col1" class="data row25 col1" >20.4°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row26" class="row_heading level0 row26" >780461</th>
#       <td id="T_df85a_row26_col0" class="data row26 col0" >2022-01-23</td>
#       <td id="T_df85a_row26_col1" class="data row26 col1" >20.3°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row27" class="row_heading level0 row27" >780462</th>
#       <td id="T_df85a_row27_col0" class="data row27 col0" >2022-01-24</td>
#       <td id="T_df85a_row27_col1" class="data row27 col1" >19.4°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row28" class="row_heading level0 row28" >780463</th>
#       <td id="T_df85a_row28_col0" class="data row28 col0" >2022-01-25</td>
#       <td id="T_df85a_row28_col1" class="data row28 col1" >20.1°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row29" class="row_heading level0 row29" >780817</th>
#       <td id="T_df85a_row29_col0" class="data row29 col0" >2023-01-14</td>
#       <td id="T_df85a_row29_col1" class="data row29 col1" >20.4°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row30" class="row_heading level0 row30" >780818</th>
#       <td id="T_df85a_row30_col0" class="data row30 col0" >2023-01-15</td>
#       <td id="T_df85a_row30_col1" class="data row30 col1" >20.4°C</td>
#     </tr>
#     <tr>
#       <th id="T_df85a_level0_row31" c
# Nāsik:
# <style type="text/css">
# #T_b3bd0 th {
#   font-size: 8pt;
# }
# </style>
# <table id="T_b3bd0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3bd0_level0_col0" class="col_heading level0 col0" >datetime</th>
#       <th id="T_b3bd0_level0_col1" class="col_heading level0 col1" >temperature_2m_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3bd0_level0_row0" class="row_heading level0 row0" >121769</th>
#       <td id="T_b3bd0_row0_col0" class="data row0 col0" >1983-05-05</td>
#       <td id="T_b3bd0_row0_col1" class="data row0 col1" >33.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_b3bd0_level0_row1" class="row_heading level0 row1" >303531</th>
#       <td id="T_b3bd0_row1_col0" class="data row1 col0" >1991-01-01</td>
#       <td id="T_b3bd0_row1_col1" class="data row1 col1" >15.3°C</td>
#     </tr>
#     <tr>
#       <th id="T_b3bd0_level0_row2" class="row_heading level0 row2" >303532</th>
#       <td id="T_b3bd0_row2_col0" class="data row2 col0" >1991-01-02</td>
#       <td id="T_b3bd0_row2_col1" class="data row2 col1" >14.8°C</td>
#     </tr>
#     <tr>
#       <th id="T_b3bd0_level0_row3" class="row_heading level0 row3" >303533</th>
#       <td id="T_b3bd0_row3_col0" class="data row3 col0" >1991-01-03</td>
#       <td id="T_b3bd0_row3_col1" class="data row3 col1" >14.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_b3bd0_level0_row4" class="row_heading level0 row4" >304641</th>
#       <td id="T_b3bd0_row4_col0" class="data row4 col0" >1994-01-15</td>
#       <td id="T_b3bd0_row4_col1" class="data row4 col1" >15.3°C</td>
#     </tr>
#     <tr>
#       <th id="T_b3bd0_level0_row5" class="row_heading level0 row5" >306214</th>
#       <td id="T_b3bd0_row5_col0" class="data row5 col0" >1998-05-07</td>
#       <td id="T_b3bd0_row5_col1" class="data row5 col1" >33.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_b3bd0_level0_row6" class="row_heading level0 row6" >483734</th>
#       <td id="T_b3bd0_row6_col0" class="data row6 col0" >2004-05-06</td>
#       <td id="T_b3bd0_row6_col1" class="data row6 col1" >33.3°C</td>
#     </tr>
#     <tr>
#       <th id="T_b3bd0_level0_row7" class="row_heading level0 row7" >485106</th>
#       <td id="T_b3bd0_row7_col0" class="data row7 col0" >2008-02-07</td>
#       <td id="T_b3bd0_row7_col1" class="data row7 col1" >14.6°C</td>
#     </tr>
#     <tr>
#       <th id="T_b3bd0_level0_row8" class="row_heading level0 row8" >485107</th>
#       <td id="T_b3bd0_row8_col0" class="data row8 col0" >2008-02-08</td>
#       <td id="T_b3bd0_row8_col1" class="data row8 col1" >14.4°C</td>
#     </tr>
#     <tr>
#       <th id="T_b3bd0_level0_row9" class="row_heading level0 row9" >668089</th>
#       <td id="T_b3bd0_row9_col0" class="data row9 col0" >2019-02-08</td>
#       <td id="T_b3bd0_row9_col1" class="data row9 col1" >14.8°C</td>
#     </tr>
#     <tr>
#       <th id="T_b3bd0_level0_row10" class="row_heading level0 row10" >668166</th>
#       <td id="T_b3bd0_row10_col0" class="data row10 col0" >2019-04-26</td>
#       <td id="T_b3bd0_row10_col1" class="data row10 col1" >33.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_b3bd0_level0_row11" class="row_heading level0 row11" >668167</th>
#       <td id="T_b3bd0_row11_col0" class="data row11 col0" >2019-04-27</td>
#       <td id="T_b3bd0_row11_col1" class="data row11 col1" >34.6°C</td>
#     </tr>
#     <tr>
#       <th id="T_b3bd0_level0_row12" class="row_heading level0 row12" >668168</th>
#       <td id="T_b3bd0_row12_col0" class="data row12 col0" >2019-04-28</td>
#       <td id="T_b3bd0_row12_col1" class="data row12 col1" >33.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_b3bd0_level0_row13" class="row_heading level0 row13" >785747</th>
#       <td id="T_b3bd0_row13_col0" class="data row13 col0" >2022-01-23</td>
#       <td id="T_b3bd0_row13_col1" class="data row13 col1" >15.1°C</td>
#     </tr>
#     <tr>
#       <th id="T_b3bd0_level0_row14" class="row_heading level0 row14" >785748</th>
#       <td id="T_b3bd0_row14_col0" class="data row14 col0" >2022-01-24</td>
#       <td id="T_b3bd0_row14_col1" class="data row14 col1" >14.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_b3bd0_level0_row15" class="row_heading level0 row15" >785749</th>
#       <td id="T_b3bd0_row15_col0" class="data row15 col0" >2022-01-25</td>
#       <td id="T_b3bd0_row15_col1" class="data row15 col1" >14.8°C</td>
#     </tr>
#     <tr>
#       <th id="T_b3bd0_level0_row16" class="row_heading level0 row16" >785842</th>
#       <td id="T_b3bd0_row16_col0" class="data row16 col0" >2022-04-28</td>
#       <td id="T_b3bd0_row16_col1" class="data row16 col1" >33.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_b3bd0_level0_row17" class="row_heading level0 row17" >786561</th>
#       <td id="T_b3bd0_row17_col0" class="data row17 col0" >2024-04-16</td>
#       <td id="T_b3bd0_row17_col1" class="data row17 col1" >33.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_b3bd0_level0_row18" class="row_heading level0 row18" >786562</th>
#       <td id="T_b3bd0_row18_col0" class="data row18 col0" >2024-04-17</td>
#       <td id="T_b3bd0_row18_col1" class="data row18 col1" >33.1°C</td>
#     </tr>
#     <tr>
#       <th id="T_b3bd0_level0_row19" class="row_heading level0 row19" >786573</th>
#       <td id="T_b3bd0_row19_col0" class="data row19 col0" >2024-04-28</td>
#       <td id="T_b3bd0_row19_col1" class="data row19 col1" >33.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_b3bd0_level0_row20" class="row_heading level0 row20" >786574</th>
#       <td id="T_b3bd0_row20_col0" class="data row20 col0" >2024-04-29</td>
#       <td id="T_b3bd0_row20_col1" class="data row20 col1" >33.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_b3bd0_level0_row21" class="row_heading level0 row21" >786596</th>
#       <td id="T_b3bd0_row21_col0" class="data row21 col0" >2024-05-21</td>
#       <td id="T_b3bd0_row21_col1" class="data row21 col1" >33.1°C</td>
#     </tr>
#   </tbody>
# </table>
# Pimpri-Chinchwad:
# <style type="text/css">
# #T_2fb4f th {
#   font-size: 8pt;
# }
# </style>
# <table id="T_2fb4f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2fb4f_level0_col0" class="col_heading level0 col0" >datetime</th>
#       <th id="T_2fb4f_level0_col1" class="col_heading level0 col1" >temperature_2m_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2fb4f_level0_row0" class="row_heading level0 row0" >128214</th>
#       <td id="T_2fb4f_row0_col0" class="data row0 col0" >1980-12-25</td>
#       <td id="T_2fb4f_row0_col1" class="data row0 col1" >15.3°C</td>
#     </tr>
#     <tr>
#       <th id="T_2fb4f_level0_row1" class="row_heading level0 row1" >129792</th>
#       <td id="T_2fb4f_row1_col0" class="data row1 col0" >1985-04-21</td>
#       <td id="T_2fb4f_row1_col1" class="data row1 col1" >32.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_2fb4f_level0_row2" class="row_heading level0 row2" >310836</th>
#       <td id="T_2fb4f_row2_col0" class="data row2 col0" >1991-01-02</td>
#       <td id="T_2fb4f_row2_col1" class="data row2 col1" >16.1°C</td>
#     </tr>
#     <tr>
#       <th id="T_2fb4f_level0_row3" class="row_heading level0 row3" >310837</th>
#       <td id="T_2fb4f_row3_col0" class="data row3 col0" >1991-01-03</td>
#       <td id="T_2fb4f_row3_col1" class="data row3 col1" >16.4°C</td>
#     </tr>
#     <tr>
#       <th id="T_2fb4f_level0_row4" class="row_heading level0 row4" >312304</th>
#       <td id="T_2fb4f_row4_col0" class="data row4 col0" >1995-01-09</td>
#       <td id="T_2fb4f_row4_col1" class="data row4 col1" >16.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_2fb4f_level0_row5" class="row_heading level0 row5" >313518</th>
#       <td id="T_2fb4f_row5_col0" class="data row5 col0" >1998-05-07</td>
#       <td id="T_2fb4f_row5_col1" class="data row5 col1" >32.6°C</td>
#     </tr>
#     <tr>
#       <th id="T_2fb4f_level0_row6" class="row_heading level0 row6" >490306</th>
#       <td id="T_2fb4f_row6_col0" class="data row6 col0" >2002-05-03</td>
#       <td id="T_2fb4f_row6_col1" class="data row6 col1" >32.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_2fb4f_level0_row7" class="row_heading level0 row7" >491037</th>
#       <td id="T_2fb4f_row7_col0" class="data row7 col0" >2004-05-03</td>
#       <td id="T_2fb4f_row7_col1" class="data row7 col1" >32.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_2fb4f_level0_row8" class="row_heading level0 row8" >492413</th>
#       <td id="T_2fb4f_row8_col0" class="data row8 col0" >2008-02-08</td>
#       <td id="T_2fb4f_row8_col1" class="data row8 col1" >16.1°C</td>
#     </tr>
#     <tr>
#       <th id="T_2fb4f_level0_row9" class="row_heading level0 row9" >672413</th>
#       <td id="T_2fb4f_row9_col0" class="data row9 col0" >2010-12-12</td>
#       <td id="T_2fb4f_row9_col1" class="data row9 col1" >16.4°C</td>
#     </tr>
#     <tr>
#       <th id="T_2fb4f_level0_row10" class="row_heading level0 row10" >673284</th>
#       <td id="T_2fb4f_row10_col0" class="data row10 col0" >2013-05-01</td>
#       <td id="T_2fb4f_row10_col1" class="data row10 col1" >32.3°C</td>
#     </tr>
#     <tr>
#       <th id="T_2fb4f_level0_row11" class="row_heading level0 row11" >675393</th>
#       <td id="T_2fb4f_row11_col0" class="data row11 col0" >2019-02-08</td>
#       <td id="T_2fb4f_row11_col1" class="data row11 col1" >16.3°C</td>
#     </tr>
#     <tr>
#       <th id="T_2fb4f_level0_row12" class="row_heading level0 row12" >675470</th>
#       <td id="T_2fb4f_row12_col0" class="data row12 col0" >2019-04-26</td>
#       <td id="T_2fb4f_row12_col1" class="data row12 col1" >32.3°C</td>
#     </tr>
#     <tr>
#       <th id="T_2fb4f_level0_row13" class="row_heading level0 row13" >675471</th>
#       <td id="T_2fb4f_row13_col0" class="data row13 col0" >2019-04-27</td>
#       <td id="T_2fb4f_row13_col1" class="data row13 col1" >32.7°C</td>
#     </tr>
#     <tr>
#       <th id="T_2fb4f_level0_row14" class="row_heading level0 row14" >789272</th>
#       <td id="T_2fb4f_row14_col0" class="data row14 col0" >2022-01-24</td>
#       <td id="T_2fb4f_row14_col1" class="data row14 col1" >15.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_2fb4f_level0_row15" class="row_heading level0 row15" >789365</th>
#       <td id="T_2fb4f_row15_col0" class="data row15 col0" >2022-04-27</td>
#       <td id="T_2fb4f_row15_col1" class="data row15 col1" >32.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_2fb4f_level0_row16" class="row_heading level0 row16" >790084</th>
#       <td id="T_2fb4f_row16_col0" class="data row16 col0" >2024-04-15</td>
#       <td id="T_2fb4f_row16_col1" class="data row16 col1" >32.4°C</td>
#     </tr>
#     <tr>
#       <th id="T_2fb4f_level0_row17" class="row_heading level0 row17" >790085</th>
#       <td id="T_2fb4f_row17_col0" class="data row17 col0" >2024-04-16</td>
#       <td id="T_2fb4f_row17_col1" class="data row17 col1" >33.7°C</td>
#     </tr>
#     <tr>
#       <th id="T_2fb4f_level0_row18" class="row_heading level0 row18" >790096</th>
#       <td id="T_2fb4f_row18_col0" class="data row18 col0" >2024-04-27</td>
#       <td id="T_2fb4f_row18_col1" class="data row18 col1" >32.6°C</td>
#     </tr>
#     <tr>
#       <th id="T_2fb4f_level0_row19" class="row_heading level0 row19" >790097</th>
#       <td id="T_2fb4f_row19_col0" class="data row19 col0" >2024-04-28</td>
#       <td id="T_2fb4f_row19_col1" class="data row19 col1" >33.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_2fb4f_level0_row20" class="row_heading level0 row20" >790098</th>
#       <td id="T_2fb4f_row20_col0" class="data row20 col0" >2024-04-29</td>
#       <td id="T_2fb4f_row20_col1" class="data row20 col1" >33.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_2fb4f_level0_row21" class="row_heading level0 row21" >790099</th>
#       <td id="T_2fb4f_row21_col0" class="data row21 col0" >2024-04-30</td>
#       <td id="T_2fb4f_row21_col1" class="data row21 col1" >32.4°C</td>
#     </tr>
#   </tbody>
# </table>
# Pune:
# <style type="text/css">
# #T_17d42 th {
#   font-size: 8pt;
# }
# </style>
# <table id="T_17d42">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17d42_level0_col0" class="col_heading level0 col0" >datetime</th>
#       <th id="T_17d42_level0_col1" class="col_heading level0 col1" >temperature_2m_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17d42_level0_row0" class="row_heading level0 row0" >135520</th>
#       <td id="T_17d42_row0_col0" class="data row0 col0" >1980-12-25</td>
#       <td id="T_17d42_row0_col1" class="data row0 col1" >15.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_17d42_level0_row1" class="row_heading level0 row1" >137098</th>
#       <td id="T_17d42_row1_col0" class="data row1 col0" >1985-04-21</td>
#       <td id="T_17d42_row1_col1" class="data row1 col1" >32.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_17d42_level0_row2" class="row_heading level0 row2" >319608</th>
#       <td id="T_17d42_row2_col0" class="data row2 col0" >1995-01-09</td>
#       <td id="T_17d42_row2_col1" class="data row2 col1" >16.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_17d42_level0_row3" class="row_heading level0 row3" >320822</th>
#       <td id="T_17d42_row3_col0" class="data row3 col0" >1998-05-07</td>
#       <td id="T_17d42_row3_col1" class="data row3 col1" >33.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_17d42_level0_row4" class="row_heading level0 row4" >497611</th>
#       <td id="T_17d42_row4_col0" class="data row4 col0" >2002-05-02</td>
#       <td id="T_17d42_row4_col1" class="data row4 col1" >32.8°C</td>
#     </tr>
#     <tr>
#       <th id="T_17d42_level0_row5" class="row_heading level0 row5" >497612</th>
#       <td id="T_17d42_row5_col0" class="data row5 col0" >2002-05-03</td>
#       <td id="T_17d42_row5_col1" class="data row5 col1" >32.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_17d42_level0_row6" class="row_heading level0 row6" >498343</th>
#       <td id="T_17d42_row6_col0" class="data row6 col0" >2004-05-03</td>
#       <td id="T_17d42_row6_col1" class="data row6 col1" >33.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_17d42_level0_row7" class="row_heading level0 row7" >680588</th>
#       <td id="T_17d42_row7_col0" class="data row7 col0" >2013-05-01</td>
#       <td id="T_17d42_row7_col1" class="data row7 col1" >32.8°C</td>
#     </tr>
#     <tr>
#       <th id="T_17d42_level0_row8" class="row_heading level0 row8" >682774</th>
#       <td id="T_17d42_row8_col0" class="data row8 col0" >2019-04-26</td>
#       <td id="T_17d42_row8_col1" class="data row8 col1" >33.1°C</td>
#     </tr>
#     <tr>
#       <th id="T_17d42_level0_row9" class="row_heading level0 row9" >682775</th>
#       <td id="T_17d42_row9_col0" class="data row9 col0" >2019-04-27</td>
#       <td id="T_17d42_row9_col1" class="data row9 col1" >33.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_17d42_level0_row10" class="row_heading level0 row10" >682776</th>
#       <td id="T_17d42_row10_col0" class="data row10 col0" >2019-04-28</td>
#       <td id="T_17d42_row10_col1" class="data row10 col1" >32.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_17d42_level0_row11" class="row_heading level0 row11" >792796</th>
#       <td id="T_17d42_row11_col0" class="data row11 col0" >2022-01-24</td>
#       <td id="T_17d42_row11_col1" class="data row11 col1" >15.8°C</td>
#     </tr>
#     <tr>
#       <th id="T_17d42_level0_row12" class="row_heading level0 row12" >792889</th>
#       <td id="T_17d42_row12_col0" class="data row12 col0" >2022-04-27</td>
#       <td id="T_17d42_row12_col1" class="data row12 col1" >32.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_17d42_level0_row13" class="row_heading level0 row13" >793608</th>
#       <td id="T_17d42_row13_col0" class="data row13 col0" >2024-04-15</td>
#       <td id="T_17d42_row13_col1" class="data row13 col1" >32.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_17d42_level0_row14" class="row_heading level0 row14" >793609</th>
#       <td id="T_17d42_row14_col0" class="data row14 col0" >2024-04-16</td>
#       <td id="T_17d42_row14_col1" class="data row14 col1" >34.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_17d42_level0_row15" class="row_heading level0 row15" >793610</th>
#       <td id="T_17d42_row15_col0" class="data row15 col0" >2024-04-17</td>
#       <td id="T_17d42_row15_col1" class="data row15 col1" >32.8°C</td>
#     </tr>
#     <tr>
#       <th id="T_17d42_level0_row16" class="row_heading level0 row16" >793620</th>
#       <td id="T_17d42_row16_col0" class="data row16 col0" >2024-04-27</td>
#       <td id="T_17d42_row16_col1" class="data row16 col1" >33.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_17d42_level0_row17" class="row_heading level0 row17" >793621</th>
#       <td id="T_17d42_row17_col0" class="data row17 col0" >2024-04-28</td>
#       <td id="T_17d42_row17_col1" class="data row17 col1" >33.8°C</td>
#     </tr>
#     <tr>
#       <th id="T_17d42_level0_row18" class="row_heading level0 row18" >793622</th>
#       <td id="T_17d42_row18_col0" class="data row18 col0" >2024-04-29</td>
#       <td id="T_17d42_row18_col1" class="data row18 col1" >33.8°C</td>
#     </tr>
#     <tr>
#       <th id="T_17d42_level0_row19" class="row_heading level0 row19" >793623</th>
#       <td id="T_17d42_row19_col0" class="data row19 col0" >2024-04-30</td>
#       <td id="T_17d42_row19_col1" class="data row19 col1" >33.3°C</td>
#     </tr>
#   </tbody>
# </table>
# Rājkot:
# <style type="text/css">
# #T_d1f45 th {
#   font-size: 8pt;
# }
# </style>
# <table id="T_d1f45">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1f45_level0_col0" class="col_heading level0 col0" >datetime</th>
#       <th id="T_d1f45_level0_col1" class="col_heading level0 col1" >temperature_2m_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1f45_level0_row0" class="row_heading level0 row0" >321790</th>
#       <td id="T_d1f45_row0_col0" class="data row0 col0" >1990-12-31</td>
#       <td id="T_d1f45_row0_col1" class="data row0 col1" >14.1°C</td>
#     </tr>
#     <tr>
#       <th id="T_d1f45_level0_row1" class="row_heading level0 row1" >321791</th>
#       <td id="T_d1f45_row1_col0" class="data row1 col0" >1991-01-01</td>
#       <td id="T_d1f45_row1_col1" class="data row1 col1" >13.6°C</td>
#     </tr>
#     <tr>
#       <th id="T_d1f45_level0_row2" class="row_heading level0 row2" >321792</th>
#       <td id="T_d1f45_row2_col0" class="data row2 col0" >1991-01-02</td>
#       <td id="T_d1f45_row2_col1" class="data row2 col1" >14.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_d1f45_level0_row3" class="row_heading level0 row3" >503371</th>
#       <td id="T_d1f45_row3_col0" class="data row3 col0" >2008-02-07</td>
#       <td id="T_d1f45_row3_col1" class="data row3 col1" >13.7°C</td>
#     </tr>
#     <tr>
#       <th id="T_d1f45_level0_row4" class="row_heading level0 row4" >683792</th>
#       <td id="T_d1f45_row4_col0" class="data row4 col0" >2012-02-08</td>
#       <td id="T_d1f45_row4_col1" class="data row4 col1" >14.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_d1f45_level0_row5" class="row_heading level0 row5" >793819</th>
#       <td id="T_d1f45_row5_col0" class="data row5 col0" >2020-01-16</td>
#       <td id="T_d1f45_row5_col1" class="data row5 col1" >14.6°C</td>
#     </tr>
#   </tbody>
# </table>
# Srīnagar:
# <style type="text/css">
# #T_5d7ab th {
#   font-size: 8pt;
# }
# </style>
# <table id="T_5d7ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d7ab_level0_col0" class="col_heading level0 col0" >datetime</th>
#       <th id="T_5d7ab_level0_col1" class="col_heading level0 col1" >temperature_2m_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d7ab_level0_row0" class="row_heading level0 row0" >692896</th>
#       <td id="T_5d7ab_row0_col0" class="data row0 col0" >2017-01-12</td>
#       <td id="T_5d7ab_row0_col1" class="data row0 col1" >-13.8°C</td>
#     </tr>
#   </tbody>
# </table>
# Sūrat:
# <style type="text/css">
# #T_56f5a th {
#   font-size: 8pt;
# }
# </style>
# <table id="T_56f5a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56f5a_level0_col0" class="col_heading level0 col0" >datetime</th>
#       <th id="T_56f5a_level0_col1" class="col_heading level0 col1" >temperature_2m_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56f5a_level0_row0" class="row_heading level0 row0" >153784</th>
#       <td id="T_56f5a_row0_col0" class="data row0 col0" >1980-12-24</td>
#       <td id="T_56f5a_row0_col1" class="data row0 col1" >18.3°C</td>
#     </tr>
#     <tr>
#       <th id="T_56f5a_level0_row1" class="row_heading level0 row1" >153785</th>
#       <td id="T_56f5a_row1_col0" class="data row1 col0" >1980-12-25</td>
#       <td id="T_56f5a_row1_col1" class="data row1 col1" >18.6°C</td>
#     </tr>
#     <tr>
#       <th id="T_56f5a_level0_row2" class="row_heading level0 row2" >154882</th>
#       <td id="T_56f5a_row2_col0" class="data row2 col0" >1983-12-27</td>
#       <td id="T_56f5a_row2_col1" class="data row2 col1" >18.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_56f5a_level0_row3" class="row_heading level0 row3" >336397</th>
#       <td id="T_56f5a_row3_col0" class="data row3 col0" >1990-12-30</td>
#       <td id="T_56f5a_row3_col1" class="data row3 col1" >18.4°C</td>
#     </tr>
#     <tr>
#       <th id="T_56f5a_level0_row4" class="row_heading level0 row4" >336398</th>
#       <td id="T_56f5a_row4_col0" class="data row4 col0" >1990-12-31</td>
#       <td id="T_56f5a_row4_col1" class="data row4 col1" >18.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_56f5a_level0_row5" class="row_heading level0 row5" >336399</th>
#       <td id="T_56f5a_row5_col0" class="data row5 col0" >1991-01-01</td>
#       <td id="T_56f5a_row5_col1" class="data row5 col1" >17.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_56f5a_level0_row6" class="row_heading level0 row6" >336400</th>
#       <td id="T_56f5a_row6_col0" class="data row6 col0" >1991-01-02</td>
#       <td id="T_56f5a_row6_col1" class="data row6 col1" >17.4°C</td>
#     </tr>
#     <tr>
#       <th id="T_56f5a_level0_row7" class="row_heading level0 row7" >336401</th>
#       <td id="T_56f5a_row7_col0" class="data row7 col0" >1991-01-03</td>
#       <td id="T_56f5a_row7_col1" class="data row7 col1" >18.3°C</td>
#     </tr>
#     <tr>
#       <th id="T_56f5a_level0_row8" class="row_heading level0 row8" >337868</th>
#       <td id="T_56f5a_row8_col0" class="data row8 col0" >1995-01-09</td>
#       <td id="T_56f5a_row8_col1" class="data row8 col1" >18.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_56f5a_level0_row9" class="row_heading level0 row9" >516900</th>
#       <td id="T_56f5a_row9_col0" class="data row9 col0" >2005-02-19</td>
#       <td id="T_56f5a_row9_col1" class="data row9 col1" >18.6°C</td>
#     </tr>
#     <tr>
#       <th id="T_56f5a_level0_row10" class="row_heading level0 row10" >517980</th>
#       <td id="T_56f5a_row10_col0" class="data row10 col0" >2008-02-04</td>
#       <td id="T_56f5a_row10_col1" class="data row10 col1" >17.6°C</td>
#     </tr>
#     <tr>
#       <th id="T_56f5a_level0_row11" class="row_heading level0 row11" >517981</th>
#       <td id="T_56f5a_row11_col0" class="data row11 col0" >2008-02-05</td>
#       <td id="T_56f5a_row11_col1" class="data row11 col1" >17.8°C</td>
#     </tr>
#     <tr>
#       <th id="T_56f5a_level0_row12" class="row_heading level0 row12" >517982</th>
#       <td id="T_56f5a_row12_col0" class="data row12 col0" >2008-02-06</td>
#       <td id="T_56f5a_row12_col1" class="data row12 col1" >18.1°C</td>
#     </tr>
#     <tr>
#       <th id="T_56f5a_level0_row13" class="row_heading level0 row13" >517983</th>
#       <td id="T_56f5a_row13_col0" class="data row13 col0" >2008-02-07</td>
#       <td id="T_56f5a_row13_col1" class="data row13 col1" >16.3°C</td>
#     </tr>
#     <tr>
#       <th id="T_56f5a_level0_row14" class="row_heading level0 row14" >517984</th>
#       <td id="T_56f5a_row14_col0" class="data row14 col0" >2008-02-08</td>
#       <td id="T_56f5a_row14_col1" class="data row14 col1" >17.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_56f5a_level0_row15" class="row_heading level0 row15" >517985</th>
#       <td id="T_56f5a_row15_col0" class="data row15 col0" >2008-02-09</td>
#       <td id="T_56f5a_row15_col1" class="data row15 col1" >18.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_56f5a_level0_row16" class="row_heading level0 row16" >698400</th>
#       <td id="T_56f5a_row16_col0" class="data row16 col0" >2012-02-08</td>
#       <td id="T_56f5a_row16_col1" class="data row16 col1" >17.8°C</td>
#     </tr>
#     <tr>
#       <th id="T_56f5a_level0_row17" class="row_heading level0 row17" >700957</th>
#       <td id="T_56f5a_row17_col0" class="data row17 col0" >2019-02-08</td>
#       <td id="T_56f5a_row17_col1" class="data row17 col1" >17.7°C</td>
#     </tr>
#     <tr>
#       <th id="T_56f5a_level0_row18" class="row_heading level0 row18" >701035</th>
#       <td id="T_56f5a_row18_col0" class="data row18 col0" >2019-04-27</td>
#       <td id="T_56f5a_row18_col1" class="data row18 col1" >36.6°C</td>
#     </tr>
#     <tr>
#       <th id="T_56f5a_level0_row19" class="row_heading level0 row19" >800867</th>
#       <td id="T_56f5a_row19_col0" class="data row19 col0" >2020-01-16</td>
#       <td id="T_56f5a_row19_col1" class="data row19 col1" >17.7°C</td>
#     </tr>
#     <tr>
#       <th id="T_56f5a_level0_row20" class="row_heading level0 row20" >800868</th>
#       <td id="T_56f5a_row20_col0" class="data row20 col0" >2020-01-17</td>
#       <td id="T_56f5a_row20_col1" class="data row20 col1" >18.1°C</td>
#     </tr>
#     <tr>
#       <th id="T_56f5a_level0_row21" class="row_heading level0 row21" >801591</th>
#       <td id="T_56f5a_row21_col0" class="data row21 col0" >2022-01-09</td>
#       <td id="T_56f5a_row21_col1" class="data row21 col1" >18.2°C</td>
#     </tr>
#     <tr>
# ...
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row4" class="row_heading level0 row4" >165867</th>
#       <td id="T_28431_row4_col0" class="data row4 col0" >1984-01-22</td>
#       <td id="T_28431_row4_col1" class="data row4 col1" >19.6°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row5" class="row_heading level0 row5" >165896</th>
#       <td id="T_28431_row5_col0" class="data row5 col0" >1984-02-20</td>
#       <td id="T_28431_row5_col1" class="data row5 col1" >20.1°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row6" class="row_heading level0 row6" >166322</th>
#       <td id="T_28431_row6_col0" class="data row6 col0" >1985-04-21</td>
#       <td id="T_28431_row6_col1" class="data row6 col1" >33.4°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row7" class="row_heading level0 row7" >166926</th>
#       <td id="T_28431_row7_col0" class="data row7 col0" >1986-12-16</td>
#       <td id="T_28431_row7_col1" class="data row7 col1" >20.3°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row8" class="row_heading level0 row8" >166927</th>
#       <td id="T_28431_row8_col0" class="data row8 col0" >1986-12-17</td>
#       <td id="T_28431_row8_col1" class="data row8 col1" >20.1°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row9" class="row_heading level0 row9" >347354</th>
#       <td id="T_28431_row9_col0" class="data row9 col0" >1990-12-31</td>
#       <td id="T_28431_row9_col1" class="data row9 col1" >20.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row10" class="row_heading level0 row10" >347355</th>
#       <td id="T_28431_row10_col0" class="data row10 col0" >1991-01-01</td>
#       <td id="T_28431_row10_col1" class="data row10 col1" >19.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row11" class="row_heading level0 row11" >347356</th>
#       <td id="T_28431_row11_col0" class="data row11 col0" >1991-01-02</td>
#       <td id="T_28431_row11_col1" class="data row11 col1" >19.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row12" class="row_heading level0 row12" >348824</th>
#       <td id="T_28431_row12_col0" class="data row12 col0" >1995-01-09</td>
#       <td id="T_28431_row12_col1" class="data row12 col1" >20.1°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row13" class="row_heading level0 row13" >349567</th>
#       <td id="T_28431_row13_col0" class="data row13 col0" >1997-01-21</td>
#       <td id="T_28431_row13_col1" class="data row13 col1" >19.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row14" class="row_heading level0 row14" >526348</th>
#       <td id="T_28431_row14_col0" class="data row14 col0" >2000-12-31</td>
#       <td id="T_28431_row14_col1" class="data row14 col1" >19.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row15" class="row_heading level0 row15" >527570</th>
#       <td id="T_28431_row15_col0" class="data row15 col0" >2004-05-06</td>
#       <td id="T_28431_row15_col1" class="data row15 col1" >32.8°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row16" class="row_heading level0 row16" >527859</th>
#       <td id="T_28431_row16_col0" class="data row16 col0" >2005-02-19</td>
#       <td id="T_28431_row16_col1" class="data row16 col1" >20.1°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row17" class="row_heading level0 row17" >527861</th>
#       <td id="T_28431_row17_col0" class="data row17 col0" >2005-02-21</td>
#       <td id="T_28431_row17_col1" class="data row17 col1" >20.3°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row18" class="row_heading level0 row18" >528939</th>
#       <td id="T_28431_row18_col0" class="data row18 col0" >2008-02-04</td>
#       <td id="T_28431_row18_col1" class="data row18 col1" >19.4°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row19" class="row_heading level0 row19" >528940</th>
#       <td id="T_28431_row19_col0" class="data row19 col0" >2008-02-05</td>
#       <td id="T_28431_row19_col1" class="data row19 col1" >18.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row20" class="row_heading level0 row20" >528941</th>
#       <td id="T_28431_row20_col0" class="data row20 col0" >2008-02-06</td>
#       <td id="T_28431_row20_col1" class="data row20 col1" >20.3°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row21" class="row_heading level0 row21" >528942</th>
#       <td id="T_28431_row21_col0" class="data row21 col0" >2008-02-07</td>
#       <td id="T_28431_row21_col1" class="data row21 col1" >17.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row22" class="row_heading level0 row22" >528943</th>
#       <td id="T_28431_row22_col0" class="data row22 col0" >2008-02-08</td>
#       <td id="T_28431_row22_col1" class="data row22 col1" >18.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row23" class="row_heading level0 row23" >709336</th>
#       <td id="T_28431_row23_col0" class="data row23 col0" >2012-01-19</td>
#       <td id="T_28431_row23_col1" class="data row23 col1" >20.1°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row24" class="row_heading level0 row24" >709356</th>
#       <td id="T_28431_row24_col0" class="data row24 col0" >2012-02-08</td>
#       <td id="T_28431_row24_col1" class="data row24 col1" >20.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row25" class="row_heading level0 row25" >710059</th>
#       <td id="T_28431_row25_col0" class="data row25 col0" >2014-01-11</td>
#       <td id="T_28431_row25_col1" class="data row25 col1" >20.4°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row26" class="row_heading level0 row26" >711913</th>
#       <td id="T_28431_row26_col0" class="data row26 col0" >2019-02-08</td>
#       <td id="T_28431_row26_col1" class="data row26 col1" >19.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row27" class="row_heading level0 row27" >711914</th>
#       <td id="T_28431_row27_col0" class="data row27 col0" >2019-02-09</td>
#       <td id="T_28431_row27_col1" class="data row27 col1" >20.3°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row28" class="row_heading level0 row28" >806153</th>
#       <td id="T_28431_row28_col0" class="data row28 col0" >2020-01-16</td>
#       <td id="T_28431_row28_col1" class="data row28 col1" >19.7°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row29" class="row_heading level0 row29" >806154</th>
#       <td id="T_28431_row29_col0" class="data row29 col0" >2020-01-17</td>
#       <td id="T_28431_row29_col1" class="data row29 col1" >19.3°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row30" class="row_heading level0 row30" >806878</th>
#       <td id="T_28431_row30_col0" class="data row30 col0" >2022-01-10</td>
#       <td id="T_28431_row30_col1" class="data row30 col1" >19.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_28431_level0_row31" c
# Vijayavāda:
# <style type="text/css">
# #T_c2219 th {
#   font-size: 8pt;
# }
# </style>
# <table id="T_c2219">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2219_level0_col0" class="col_heading level0 col0" >datetime</th>
#       <th id="T_c2219_level0_col1" class="col_heading level0 col1" >temperature_2m_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2219_level0_row0" class="row_heading level0 row0" >168179</th>
#       <td id="T_c2219_row0_col0" class="data row0 col0" >1980-05-21</td>
#       <td id="T_c2219_row0_col1" class="data row0 col1" >37.8°C</td>
#     </tr>
#     <tr>
#       <th id="T_c2219_level0_row1" class="row_heading level0 row1" >168181</th>
#       <td id="T_c2219_row1_col0" class="data row1 col0" >1980-05-23</td>
#       <td id="T_c2219_row1_col1" class="data row1 col1" >37.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_c2219_level0_row2" class="row_heading level0 row2" >168182</th>
#       <td id="T_c2219_row2_col0" class="data row2 col0" >1980-05-24</td>
#       <td id="T_c2219_row2_col1" class="data row2 col1" >38.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_c2219_level0_row3" class="row_heading level0 row3" >168183</th>
#       <td id="T_c2219_row3_col0" class="data row3 col0" >1980-05-25</td>
#       <td id="T_c2219_row3_col1" class="data row3 col1" >38.4°C</td>
#     </tr>
#     <tr>
#       <th id="T_c2219_level0_row4" class="row_heading level0 row4" >171110</th>
#       <td id="T_c2219_row4_col0" class="data row4 col0" >1988-05-30</td>
#       <td id="T_c2219_row4_col1" class="data row4 col1" >38.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_c2219_level0_row5" class="row_heading level0 row5" >530496</th>
#       <td id="T_c2219_row5_col0" class="data row5 col0" >2002-05-10</td>
#       <td id="T_c2219_row5_col1" class="data row5 col1" >38.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_c2219_level0_row6" class="row_heading level0 row6" >530497</th>
#       <td id="T_c2219_row6_col0" class="data row6 col0" >2002-05-11</td>
#       <td id="T_c2219_row6_col1" class="data row6 col1" >38.3°C</td>
#     </tr>
#     <tr>
#       <th id="T_c2219_level0_row7" class="row_heading level0 row7" >530499</th>
#       <td id="T_c2219_row7_col0" class="data row7 col0" >2002-05-13</td>
#       <td id="T_c2219_row7_col1" class="data row7 col1" >38.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_c2219_level0_row8" class="row_heading level0 row8" >530873</th>
#       <td id="T_c2219_row8_col0" class="data row8 col0" >2003-05-22</td>
#       <td id="T_c2219_row8_col1" class="data row8 col1" >37.8°C</td>
#     </tr>
#     <tr>
#       <th id="T_c2219_level0_row9" class="row_heading level0 row9" >530881</th>
#       <td id="T_c2219_row9_col0" class="data row9 col0" >2003-05-30</td>
#       <td id="T_c2219_row9_col1" class="data row9 col1" >38.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_c2219_level0_row10" class="row_heading level0 row10" >530882</th>
#       <td id="T_c2219_row10_col0" class="data row10 col0" >2003-05-31</td>
#       <td id="T_c2219_row10_col1" class="data row10 col1" >38.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_c2219_level0_row11" class="row_heading level0 row11" >530886</th>
#       <td id="T_c2219_row11_col0" class="data row11 col0" >2003-06-04</td>
#       <td id="T_c2219_row11_col1" class="data row11 col1" >38.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_c2219_level0_row12" class="row_heading level0 row12" >713118</th>
#       <td id="T_c2219_row12_col0" class="data row12 col0" >2012-05-28</td>
#       <td id="T_c2219_row12_col1" class="data row12 col1" >38.1°C</td>
#     </tr>
#     <tr>
#       <th id="T_c2219_level0_row13" class="row_heading level0 row13" >713121</th>
#       <td id="T_c2219_row13_col0" class="data row13 col0" >2012-05-31</td>
#       <td id="T_c2219_row13_col1" class="data row13 col1" >38.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_c2219_level0_row14" class="row_heading level0 row14" >713479</th>
#       <td id="T_c2219_row14_col0" class="data row14 col0" >2013-05-24</td>
#       <td id="T_c2219_row14_col1" class="data row14 col1" >38.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_c2219_level0_row15" class="row_heading level0 row15" >714207</th>
#       <td id="T_c2219_row15_col0" class="data row15 col0" >2015-05-22</td>
#       <td id="T_c2219_row15_col1" class="data row15 col1" >38.4°C</td>
#     </tr>
#     <tr>
#       <th id="T_c2219_level0_row16" class="row_heading level0 row16" >714208</th>
#       <td id="T_c2219_row16_col0" class="data row16 col0" >2015-05-23</td>
#       <td id="T_c2219_row16_col1" class="data row16 col1" >38.3°C</td>
#     </tr>
#     <tr>
#       <th id="T_c2219_level0_row17" class="row_heading level0 row17" >714209</th>
#       <td id="T_c2219_row17_col0" class="data row17 col0" >2015-05-24</td>
#       <td id="T_c2219_row17_col1" class="data row17 col1" >38.4°C</td>
#     </tr>
#     <tr>
#       <th id="T_c2219_level0_row18" class="row_heading level0 row18" >714210</th>
#       <td id="T_c2219_row18_col0" class="data row18 col0" >2015-05-25</td>
#       <td id="T_c2219_row18_col1" class="data row18 col1" >38.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_c2219_level0_row19" class="row_heading level0 row19" >714211</th>
#       <td id="T_c2219_row19_col0" class="data row19 col0" >2015-05-26</td>
#       <td id="T_c2219_row19_col1" class="data row19 col1" >38.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_c2219_level0_row20" class="row_heading level0 row20" >714934</th>
#       <td id="T_c2219_row20_col0" class="data row20 col0" >2017-05-18</td>
#       <td id="T_c2219_row20_col1" class="data row20 col1" >37.8°C</td>
#     </tr>
#   </tbody>
# </table>
# Vishākhapatnam:
# <style type="text/css">
# #T_11387 th {
#   font-size: 8pt;
# }
# </style>
# <table id="T_11387">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11387_level0_col0" class="col_heading level0 col0" >datetime</th>
#       <th id="T_11387_level0_col1" class="col_heading level0 col1" >temperature_2m_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11387_level0_row0" class="row_heading level0 row0" >172068</th>
#       <td id="T_11387_row0_col0" class="data row0 col0" >1981-01-12</td>
#       <td id="T_11387_row0_col1" class="data row0 col1" >18.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_11387_level0_row1" class="row_heading level0 row1" >173304</th>
#       <td id="T_11387_row1_col0" class="data row1 col0" >1984-06-01</td>
#       <td id="T_11387_row1_col1" class="data row1 col1" >35.8°C</td>
#     </tr>
#     <tr>
#       <th id="T_11387_level0_row2" class="row_heading level0 row2" >173665</th>
#       <td id="T_11387_row2_col0" class="data row2 col0" >1985-05-28</td>
#       <td id="T_11387_row2_col1" class="data row2 col1" >36.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_11387_level0_row3" class="row_heading level0 row3" >352626</th>
#       <td id="T_11387_row3_col0" class="data row3 col0" >1995-06-08</td>
#       <td id="T_11387_row3_col1" class="data row3 col1" >35.5°C</td>
#     </tr>
#     <tr>
#       <th id="T_11387_level0_row4" class="row_heading level0 row4" >353711</th>
#       <td id="T_11387_row4_col0" class="data row4 col0" >1998-05-28</td>
#       <td id="T_11387_row4_col1" class="data row4 col1" >36.1°C</td>
#     </tr>
#     <tr>
#       <th id="T_11387_level0_row5" class="row_heading level0 row5" >353712</th>
#       <td id="T_11387_row5_col0" class="data row5 col0" >1998-05-29</td>
#       <td id="T_11387_row5_col1" class="data row5 col1" >35.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_11387_level0_row6" class="row_heading level0 row6" >534150</th>
#       <td id="T_11387_row6_col0" class="data row6 col0" >2002-05-11</td>
#       <td id="T_11387_row6_col1" class="data row6 col1" >37.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_11387_level0_row7" class="row_heading level0 row7" >534151</th>
#       <td id="T_11387_row7_col0" class="data row7 col0" >2002-05-12</td>
#       <td id="T_11387_row7_col1" class="data row7 col1" >37.2°C</td>
#     </tr>
#     <tr>
#       <th id="T_11387_level0_row8" class="row_heading level0 row8" >535282</th>
#       <td id="T_11387_row8_col0" class="data row8 col0" >2005-06-16</td>
#       <td id="T_11387_row8_col1" class="data row8 col1" >35.7°C</td>
#     </tr>
#     <tr>
#       <th id="T_11387_level0_row9" class="row_heading level0 row9" >717132</th>
#       <td id="T_11387_row9_col0" class="data row9 col0" >2013-05-25</td>
#       <td id="T_11387_row9_col1" class="data row9 col1" >36.0°C</td>
#     </tr>
#     <tr>
#       <th id="T_11387_level0_row10" class="row_heading level0 row10" >719178</th>
#       <td id="T_11387_row10_col0" class="data row10 col0" >2018-12-31</td>
#       <td id="T_11387_row10_col1" class="data row10 col1" >18.9°C</td>
#     </tr>
#     <tr>
#       <th id="T_11387_level0_row11" class="row_heading level0 row11" >810918</th>
#       <td id="T_11387_row11_col0" class="data row11 col0" >2023-06-10</td>
#       <td id="T_11387_row11_col1" class="data row11 col1" >36.6°C</td>
#     </tr>
#     <tr>
#       <th id="T_11387_level0_row12" class="row_heading level0 row12" >810919</th>
#       <td id="T_11387_row12_col0" class="data row12 col0" >2023-06-11</td>
#       <td id="T_11387_row12_col1" class="data row12 col1" >36.3°C</td>
#     </tr>
#     <tr>
#       <th id="T_11387_level0_row13" class="row_heading level0 row13" >810924</th>
#       <td id="T_11387_row13_col0" class="data row13 col0" >2023-06-16</td>
#       <td id="T_11387_row13_col1" class="data row13 col1" >35.9°C</td>
#     </tr>
#   </tbody>
# </table>

# %%
# %%
# Enhanced Boxplot with better spacing and visibility
plt.figure(figsize=(14, 7))  # Wider figure for better spacing

# Create the boxplot with adjusted parameters
box = sns.boxplot(data=df_final, x='city_name', y='temperature_2m_mean',
                 palette="coolwarm",  # Color scheme
                 width=0.6,          # Adjust box width
                 linewidth=1.5,      # Thicker box lines
                 fliersize=4)        # Outlier marker size

# Enhance title and labels
plt.title('Temperature Distribution by City (with Outliers)', 
          fontsize=14, pad=20, weight='bold')
plt.xlabel('City', fontsize=12, labelpad=10)
plt.ylabel('Mean Temperature (°C)', fontsize=12, labelpad=10)

# Improve x-axis city labels
box.set_xticklabels(box.get_xticklabels(), 
                   rotation=45, 
                   ha='right', 
                   fontsize=10)

# Add horizontal grid lines
plt.grid(True, axis='y', alpha=0.3, linestyle='--')

# Adjust city spacing
plt.xlim(-0.8, len(df_final['city_name'].unique())-0.2)  # Wider spacing
box.margins(x=0.05)  # Add small margin on sides

# Add annotation for outliers
plt.annotate('Circles show temperature outliers',
            xy=(0.02, 0.95), xycoords='axes fraction',
            fontsize=10, color='gray')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\RUDRA\AppData\Local\Temp\ipykernel_16656\175199107.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   box = sns.boxplot(data=df_final, x='city_name', y='temperature_2m_mean',
# C:\Users\RUDRA\AppData\Local\Temp\ipykernel_16656\175199107.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   box.set_xticklabels(box.get_xticklabels(),

# %%
# Detect outliers using IQR method
def detect_outliers_iqr(data, column):
    """Detect outliers using IQR method"""
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
    return outliers
    temp_outliers = detect_outliers_iqr(df_final, 'temperature_2m_mean')
    print(f"Number of temperature outliers: {len(temp_outliers)}")

# %%
# Handle outliers - cap them at reasonable values
def cap_outliers(data, column):
    """Cap outliers at 1.5*IQR bounds"""
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    data[column] = data[column].clip(lower_bound, upper_bound)
    return data

df_final = cap_outliers(df_final, 'temperature_2m_mean')

# Verify outliers were handled
temp_outliers = detect_outliers_iqr(df_final, 'temperature_2m_mean')
print(f"Number of temperature outliers after capping: {len(temp_outliers)}")
# Out:
# Number of temperature outliers after capping: 0

# %%
# Log transformation for precipitation (many zeros)
df_final['precipitation_log'] = np.log1p(df_final['precipitation_sum'])

plt.figure(figsize=(12, 6))
sns.histplot(df_final['precipitation_log'], bins=30, kde=True)
plt.title('Log-Transformed Precipitation Distribution', pad=20)
plt.xlabel('Log(Precipitation + 1)')
plt.ylabel('Frequency')
plt.show()

# %%
## 8. Data Visualization

# %%
# Temperature distribution by season and city
plt.figure(figsize=(14, 8))
sns.boxplot(data=df_final, x='season', y='temperature_2m_mean', hue='city_name')
plt.title('Temperature Distribution by Season and City', pad=20)
plt.xlabel('Season')
plt.ylabel('Mean Temperature (°C)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
# Wind speed vs. temperature
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df_final, x='temperature_2m_mean', y='wind_speed_10m_max', 
                hue='city_name', alpha=0.6)
plt.title('Wind Speed vs. Temperature by City', pad=20)
plt.xlabel('Mean Temperature (°C)')
plt.ylabel('Max Wind Speed (km/h)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
# Precipitation patterns by month
plt.figure(figsize=(14, 8))
sns.barplot(data=df_final, x='month', y='precipitation_sum', hue='city_name', 
            estimator=np.mean, ci=None)
plt.title('Average Monthly Precipitation by City', pad=20)
plt.xlabel('Month')
plt.ylabel('Average Precipitation (mm)')
plt.xticks(range(12), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
                      'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
# C:\Users\RUDRA\AppData\Local\Temp\ipykernel_16656\557357493.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df_final, x='month', y='precipitation_sum', hue='city_name',

# %%
# Temperature range analysis
plt.figure(figsize=(14, 8))
sns.lineplot(data=df_final, x='month', y='temperature_range', hue='city_name', 
             ci=None, estimator='mean', marker='o')
plt.title('Average Monthly Temperature Range by City', pad=20)
plt.xlabel('Month')
plt.ylabel('Temperature Range (°C)')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
                          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()
# Out:
# C:\Users\RUDRA\AppData\Local\Temp\ipykernel_16656\2246329381.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=df_final, x='month', y='temperature_range', hue='city_name',

# %%
print("Key Findings:")
print("1. Temperature patterns vary significantly by city and season.")
print("2. The hottest months are typically June-August (Summer).")
print("3. Precipitation patterns differ across cities, with some showing distinct wet/dry seasons.")
print("4. Temperature ranges (difference between max and min) are highest in Spring and Autumn.")
print("5. Wind speeds tend to be higher during colder months in most cities.")
# Out:
# Key Findings:
# 1. Temperature patterns vary significantly by city and season.
# 2. The hottest months are typically June-August (Summer).
# 3. Precipitation patterns differ across cities, with some showing distinct wet/dry seasons.
# 4. Temperature ranges (difference between max and min) are highest in Spring and Autumn.
# 5. Wind speeds tend to be higher during colder months in most cities.
